# %% [markdown]
# # **Analysis Sentimen Find Indonesia Tourism**
#
# Find Indonesia Tourism provide solution for foreign and local tourist that confused about tourist attractions in Indonesia. With sentiment analysis, we get into the app with Machine Learning, this feature will be add in search box, this will predict what the best tourist attraction based on users reviews analysis sentiment.

# %% [markdown]
# # **BUILD SEARCH BOX WITH NLP SENTIMENT ANALYSIS**

# %% [markdown]
# ## Plan of Action
#
#
# 1.   Load **GOOGLE MAPS API REVIEW**
# 2.   **Pre-process dataset** by removing special characters, numbers, etc. from user reviews + convert **sentiment labels** positive & negative to numbers 1 & 0, respectively
# 3.   **Import GloVe Word Embedding** to build Embedding Dictionary + Use this to build Embedding Matrix for our Corpus
# 4. Model Training using **Deep Learning in Keras** for separate: **CNN Models** and analyse model performance and results
# 4. Last, perform **predictions on real MAPS reviews**

# %% [markdown]
# ## Setting Environment

# %% [markdown]
# ***Mount the drive to connect with Google Drive, to access the files needed later***

# %%
# Mounting google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ***Run this code below to ensure Tensorflow is used***

# %%
# Run this to ensure TensorFlow 2.x is used
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# ***Import all the libraries needed to run the program later***

# %%
# Importing essential libraries and functions

import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from numpy import array
import csv

import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from tensorflow.keras.layers import Flatten, GlobalMaxPooling1D, Embedding, Conv1D, LSTM
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Preparation (Load Data)
#
# The datased obtained from google maps reviews that have collected in every place tourist attraction from Indonesia. This sentence has two emotional tone, 1 (positive) and 0 (negative).

# %%
with open("/content/drive/Othercomputers/My Laptop/Bangkit Academy/capstone project/csvjson (4).json", 'r') as f:
  datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['texts'])
    labels.append(item['target'])

# %% [markdown]
# Do the "Print" process with loops to see all the contents of the existing dataset

# %%
for i in range(len(datastore)):
    print(f"{datastore[i]}")
# Out:
# {'target': 0, 'texts': 'Monday, Many tours in Surabaya are closed.'}
# {'target': 1, 'texts': 'Great Place for sightseeing and spending time with friends or family'}
# {'target': 1, 'texts': 'Cool place, comfortable, clean, unlike other squares, this place has a unique architecture and layout'}
# {'target': 1, 'texts': 'Place of education for the citizens of Surabaya in particular and society in general.'}
# {'target': 1, 'texts': 'Really good'}
# {'target': 1, 'texts': 'Lots of good smooth'}
# {'target': 1, 'texts': 'Clean, well-maintained, bright and cool'}
# {'target': 1, 'texts': "The Suroboyo children's creative activity center is here. Always well maintained by the municipal government of Surabaya"}
# {'target': 1, 'texts': "I've been here several times and this is the first time the smoke from the fountain appears, yeeaay"}
# {'target': 1, 'texts': 'Very good, very familyable'}
# {'target': 1, 'texts': 'Unique'}
# {'target': 1, 'texts': 'Surabaya icon Exciting'}
# {'target': 1, 'texts': 'Surabaya residents must come here to take part in activities every weekend, namely creative home training'}
# {'target': 1, 'texts': 'The place is nice, it could be an icon of Surabaya .'}
# {'target': 1, 'texts': 'the first time here, it turned out to be good, when compared to Jakarta, what do you pay. very different here. Just enter the art museum, free parking is also free, wow'}
# {'target': 1, 'texts': 'Cozy atmosphere in the gallery'}
# {'target': 1, 'texts': 'Really good'}
# {'target': 1, 'texts': 'There are many good spots to take pictures and make memories in Surabaya'}
# {'target': 0, 'texts': "it's really crowded when it's nighttime I have to go there again"}
# {'target': 0, 'texts': 'highly recommended holding an event here, Balai Pemuda. even though the air is super hot outside SBY.'}
# {'target': 1, 'texts': 'the place is comfortable'}
# {'target': 1, 'texts': 'Many spot to enjoy, from jogging track, viewpoint, water cycle and boat trip that will take you to see mangrove ecosystem'}
# {'target': 0, 'texts': 'There is no server yet'}
# {'target': 1, 'texts': 'Mangrove tours near the house, really suitable at the end of the month to come here with family'}
# {'target': 1, 'texts': "The place is nice, perfect for refreshing your mind for a moment, construction is already underway, the facilities are quite adequate, the only problem is access to the driveway because it's still under construction"}
# {'target': 0, 'texts': 'The location is still as it is  not well maintained, even though there are many spots that are still a lot to explore  far from the Wonorejo mangroves'}
# {'target': 1, 'texts': "It's a clean and good area"}
# {'target': 0, 'texts': 'Free entry, just pay for parking. Nice place, lots of photo spots'}
# {'target': 1, 'texts': 'New mountain mangrove tour, Rungkut-Surabaya'}
# {'target': 1, 'texts': 'Cool'}
# {'target': 1, 'texts': "Natural, beautiful  It's better to come early in the morning before 8."}
# {'target': 1, 'texts': 'great as a means of learning science, especially about mangrove forest ecosystems'}
# {'target': 1, 'texts': 'Cheap tourist attractions, complete here'}
# {'target': 1, 'texts': "The place is comfortable, you can relieve fatigue and stress  it's better to come in the morning or evening  if it's hot during the day, it's really hot"}
# {'target': 1, 'texts': 'Mount Anyar Mangrove Forest looking for cool but free tourist attractions in\xa0Surabaya is the solution.'}
# {'target': 1, 'texts': 'Very cool'}
# {'target': 1, 'texts': 'The place is nice, comfortable and clean for recommended family tourism'}
# {'target': 1, 'texts': 'There are 2 mangroves there, one of the roads is badly damaged, mud thok  go back to the cat finally  to the mangroves the only road is paved  a jogging track not too wide  so just take a moment  parking for 5 thousand, there is a toilet also'}
# {'target': 1, 'texts': 'Mantab clean cheap free travel'}
# {'target': 1, 'texts': 'Free nature tourism that only pays for parking fees with quite complete and child-friendly facilities.'}
# {'target': 1, 'texts': 'Beautiful beautiful cool.'}
# {'target': 1, 'texts': 'Nice and beautiful. Suitable for roads'}
# {'target': 1, 'texts': 'The place is cool, comfortable, clean, lots of places to sit" if you are tired of walking, the road is wide, recommended for thin healing'}
# {'target': 1, 'texts': 'Looking for cool but free tourist spots in\xa0Surabaya, Gunung Anyar Mangrove Forest is the solution. This destination with an ecotourism concept is located on Jalan Medokan Sawah, Medokan Ayu Village, Rungkut District, Gunung Anyar Tambak, Gunung Anyar.'}
# {'target': 1, 'texts': 'cool place on the outskirts of the metropolis'}
# {'target': 1, 'texts': 'Nice, clean, good for photo spots'}
# {'target': 1, 'texts': "It's great that the trees are well cared for"}
# {'target': 1, 'texts': 'Make the garden more beautiful'}
# {'target': 0, 'texts': 'Now many sports facilities are damaged'}
# {'target': 1, 'texts': 'Okay'}
# {'target': 1, 'texts': 'The choice of a light hangout destination with the kids in the afternoon'}
# {'target': 1, 'texts': 'Wow siipp'}
# {'target': 1, 'texts': 'Not bad for a place to relax while eating toast 😁'}
# {'target': 1, 'texts': "Park with children's play facilities, there are futsal and basketball courts, swings, slides, several sports equipment and reflection stones, the park is clean, not bad for playing with children, across from it there are delicious meatballs, reog meatballs"}
# {'target': 1, 'texts': 'Nice place for clean up my mind'}
# {'target': 1, 'texts': 'attractive'}
# {'target': 1, 'texts': 'The road under the bridge looks like it has not been maintained, the color has become plain, there is no shelter anymore'}
# {'target': 1, 'texts': "It's pretty clean & not too hot, because there are lots of trees, lots of culinary & various kinds of knick-knacks sold here, clothes are also available even though there aren't too many visitors"}
# {'target': 1, 'texts': 'Entrance tickets can be purchased online or on the spot (on location).'}
# {'target': 1, 'texts': 'Good  More and more facilities'}
# {'target': 1, 'texts': 'Decent place for holidays with family or friends, lots of culinary menu choices.'}
# {'target': 1, 'texts': 'An inexpensive recreation area, a variety of culinary delights and a center for souvenirs.'}
# {'target': 1, 'texts': 'Relax, but cleanliness needs to be improved'}
# {'target': 1, 'texts': 'Recommended'}
# {'target': 1, 'texts': 'Recreational places are cheap and affordable'}
# {'target': 1, 'texts': "The place is nice  Now it's clean, plus there is a new bridge, it's even more beautiful"}
# {'target': 1, 'texts': 'Nice place'}
# {'target': 1, 'texts': 'Complete place'}
# {'target': 1, 'texts': 'Just normal'}
# {'target': 1, 'texts': 'Old Kenjeran Beach is now a better, cleaner and more comfortable place to gather with family or friends, the ticket prices are also affordable'}
# {'target': 1, 'texts': "now it's pretty good and neat"}
# {'target': 1, 'texts': 'Many Good Beach Cracker Traders Suitable For Holidays Or Just Come Here'}
# {'target': 1, 'texts': 'Super more comfortable now though'}
# {'target': 1, 'texts': 'Folk beach tourism'}
# {'target': 1, 'texts': 'Nice bridge to see the view'}
# {'target': 1, 'texts': 'The place is clean, MSMEs are very functioning, service   traders are good and friendly'}
# {'target': 1, 'texts': 'very worth it'}
# {'target': 1, 'texts': 'Nice Place On The Edge Of Kenjeran Beach'}
# {'target': 1, 'texts': 'Good scenery'}
# {'target': 1, 'texts': 'Big pagoda, and wide sea view'}
# {'target': 1, 'texts': 'Enter via the park gate. 5k per person, the place is clean, the people are good'}
# {'target': 1, 'texts': 'Nice place to take pictures'}
# {'target': 1, 'texts': 'Crowded, full of many people when'}
# {'target': 1, 'texts': 'The beautiful Goddess of Mercy Statue in Surabaya.'}
# {'target': 1, 'texts': 'The last time i went to Kenjeran place was like yonks ago where im still like in prep.'}
# {'target': 1, 'texts': 'Budha temple  great place'}
# {'target': 1, 'texts': 'Keren, I love it.'}
# {'target': 1, 'texts': 'Good'}
# {'target': 1, 'texts': 'A very beautiful place to enjoy the island of Madura and Off the Ferry Boat'}
# {'target': 1, 'texts': 'The stitches are neat and good'}
# {'target': 1, 'texts': 'The busiest port   Always operating 24 hours'}
# {'target': 1, 'texts': 'Nice atmosphere but very hot during the day'}
# {'target': 1, 'texts': 'Nice'}
# {'target': 1, 'texts': 'good place to spend time and take pictures'}
# {'target': 1, 'texts': 'The sea view is good'}
# {'target': 0, 'texts': 'Expensive, the view does not match expectations'}
# {'target': 1, 'texts': 'Not bad for hanging out while chatting'}
# {'target': 1, 'texts': 'Nothing at all'}
# {'target': 1, 'texts': "the shop doesn't exist. fake aliases."}
# {'target': 1, 'texts': 'Less organized'}
# {'target': 0, 'texts': 'Dirty'}
# {'target': 1, 'texts': "It's just a small alleyway. Okay for industrial old building photography theme. Nothing else."}
# {'target': 1, 'texts': 'Many old buildings as cultural heritage, every Saturday and Sunday many people visit Jalan Gula, spot Photo'}
# {'target': 1, 'texts': 'The only good for photos is the end of the sugar road from the rubber road.'}
# {'target': 1, 'texts': "It's not as good as it used to be, many murals are not clear."}
# {'target': 0, 'texts': 'Not really recommended'}
# {'target': 1, 'texts': 'Creepy Old Houses'}
# {'target': 0, 'texts': 'Not anymore'}
# {'target': 1, 'texts': 'good for photo spots, right and left of the old building,'}
# {'target': 0, 'texts': "it's so crowded that it's not well-maintained now"}
# {'target': 1, 'texts': 'An interesting place for an Instagrammable photo location'}
# {'target': 1, 'texts': 'Not bad for a vintage photo'}
# {'target': 1, 'texts': "It's actually a good photo spot."}
# {'target': 1, 'texts': 'Not bad for remembering old times.'}
# {'target': 1, 'texts': 'this place is in an alley and not too long,'}
# {'target': 1, 'texts': 'The old city in the Surabaya area, which has lots of ancient buildings'}
# {'target': 1, 'texts': "It's normal, but how come the photo"}
# {'target': 1, 'texts': 'Children love to play in this park'}
# {'target': 1, 'texts': 'The atmosphere is cool in the middle of the scorching heat of Surabaya'}
# {'target': 1, 'texts': 'Clean and comfortable suitable for sports and playing'}
# {'target': 1, 'texts': 'Excellent'}
# {'target': 1, 'texts': 'One of the green open spaces'}
# {'target': 0, 'texts': 'less parking as input'}
# {'target': 1, 'texts': "It's fun with a life partner"}
# {'target': 1, 'texts': 'Very satisfactor'}
# {'target': 1, 'texts': "It's good, the park is clean, it's quite spacious"}
# {'target': 1, 'texts': 'Quick and tidy'}
# {'target': 0, 'texts': 'Nyesell tired of taking the train'}
# {'target': 1, 'texts': "It's enough to just refresh with the kids, it's just that the place is small and in the middle of the city"}
# {'target': 1, 'texts': 'Recommended'}
# {'target': 1, 'texts': 'Suitable for accompanying children to play'}
# {'target': 1, 'texts': "It's clean enough, the park staff is also friendly"}
# {'target': 1, 'texts': 'Clean and good playground park in surabaya.'}
# {'target': 1, 'texts': 'A place that is minimal and turned into a beautiful park with quite complete facilities makes people want to visit the next day'}
# {'target': 1, 'texts': 'There have been many improvements on the side of the playground and park.'}
# {'target': 1, 'texts': "a place besides delivering small children to play, there are quite a lot of games, a place if you're bored and relaxed, from morning to evening,"}
# {'target': 1, 'texts': "Legen which is sold across the street tastes pretty good  The ingredients are delicious  The snacks are also cheap  1000's all"}
# {'target': 0, 'texts': 'There is no beer in Surabaya'}
# {'target': 1, 'texts': 'The place is comfortable for night running community gathering'}
# {'target': 1, 'texts': 'Great for selfies'}
# {'target': 0, 'texts': "How come the picture doesn't match, the real one doesn't have a futsal field"}
# {'target': 0, 'texts': 'Lack of synthetic grass futsal field was heavily damaged'}
# {'target': 0, 'texts': 'Parking attendants everywhere. Stop everywhere told to pay. Critical.'}
# {'target': 0, 'texts': 'Many street vendors are small'}
# {'target': 0, 'texts': 'A lot of people'}
# {'target': 0, 'texts': 'parking lot is expensive'}
# {'target': 0, 'texts': 'Slow service'}
# {'target': 0, 'texts': 'Bad urine odor'}
# {'target': 0, 'texts': 'impressive and beautiful'}
# {'target': 0, 'texts': 'Messy place'}
# {'target': 0, 'texts': 'Less members'}
# {'target': 0, 'texts': 'Dirty'}
# {'target': 0, 'texts': 'bad place for sure'}
# {'target': 0, 'texts': 'Transportation is difficult for foreigners.'}
# {'target': 0, 'texts': 'You need to get a taxi good luck.'}
# {'target': 0, 'texts': 'Nothing to see. Foods taste bad, the price is expensive.'}
# {'target': 0, 'texts': 'Not a tourist destination. Seriously, there is nothing to see or eat here.'}
# {'target': 0, 'texts': 'Public rubbish everywhere.'}
# {'target': 0, 'texts': 'The place was a messed up place'}
# {'target': 0, 'texts': 'Dirty, less sign'}
# {'target': 0, 'texts': 'I got scammed there'}
# {'target': 1, 'texts': 'Ok'}
# {'target': 0, 'texts': 'Not humiliate at all'}
# {'target': 0, 'texts': 'Polluted, poor WiFi, dirty'}
# {'target': 0, 'texts': 'no nope'}
# {'target': 0, 'texts': 'Wrong open closed time'}
# {'target': 0, 'texts': 'Out of expectations'}
# {'target': 0, 'texts': 'Bad facility'}
# {'target': 0, 'texts': 'Bad service'}
# {'target': 0, 'texts': 'Nothing really'}
# {'target': 0, 'texts': 'Horrible'}
# {'target': 0, 'texts': "Don't buy food and drinks here"}
# {'target': 0, 'texts': 'Not recommended.'}
# {'target': 0, 'texts': 'Nice place'}
# {'target': 1, 'texts': 'God  N sipp'}
# {'target': 1, 'texts': "Casting baramundi here can also payus. The place is spacious, cak Baygon is friendly but hilarious, all in all it's delicious, there's a coffee shop too, the motorbike parking is safe. He's the best"}
# {'target': 1, 'texts': 'Cool spot for fishing, cheap, only 10K. You can fish as much josssss'}
# {'target': 1, 'texts': 'The cheapest daily fishing is only 10 thousand and the fish are great'}
# {'target': 1, 'texts': "The daily fishing spots in the Surabaya area are relatively cheap, just 10,000, eits, don't forget to bring an umbrella, okay"}
# {'target': 1, 'texts': 'Htm 10k, patient gelem tree must be by big fish'}
# {'target': 1, 'texts': 'cheap fishing spots, wide areas, free bait, milkfish tilapia dominant fish, those who are afraid of the heat bring your own umbrella'}
# {'target': 1, 'texts': 'Pretty big fish, still curious, not satisfied with the results'}
# {'target': 1, 'texts': "I think it's good for fishing, try it when I go there."}
# {'target': 1, 'texts': "It's a shame the fish are cruising so they don't eat"}
# {'target': 1, 'texts': 'This beloved pond is lur  Cheap and cheerful There is a shop. The old fish is big'}
# {'target': 1, 'texts': 'The pond is very wide suitable for fish farming'}
# {'target': 1, 'texts': 'Gut test spot'}
# {'target': 1, 'texts': 'Not bad bite'}
# {'target': 1, 'texts': 'Good place to buy some snacks for those who needs vitamin sea 🏝'}
# {'target': 1, 'texts': "I love the bridge . especially during this horrible pandemic and force people to quarantine but for me it's cool and gorgeous the view when there's no vehicles surrounding me ."}
# {'target': 1, 'texts': "A nice place to see the sun rise. I don't know about the view of the fountain at night because I haven't gone there at night."}
# {'target': 1, 'texts': 'A nice place to have an afternoon stroll and taje picture. You can see Suramadu bridge from this place.'}
# {'target': 1, 'texts': 'Good place for family vacay and enjoying the view of the beach kenjeran'}
# {'target': 1, 'texts': 'you have to stop by here while cycling'}
# {'target': 0, 'texts': 'Could not park here.  Parking is far away and you have to walk quite far to reach the centre of the bridge'}
# {'target': 1, 'texts': 'This bridge have a beautiful landscape.'}
# {'target': 1, 'texts': 'Wonderful'}
# {'target': 1, 'texts': 'The bridge is closed for vehicle in the afternoon. So, the locals can use it as an attraction. Watch out of the strong crosswind.'}
# {'target': 1, 'texts': "Nice place to visit especially when it's sun sets. Beautiful."}
# {'target': 1, 'texts': 'It is looking so great at night because there is so many beautiful lights in this Surabaya bridge'}
# {'target': 1, 'texts': 'Place to refresh your mind'}
# {'target': 1, 'texts': 'A nice place to hanging around  Have various street food waiting for visitors'}
# {'target': 1, 'texts': 'You could see the bridge from kenjeran lama park and also the beautiful sunrise moment'}
# {'target': 1, 'texts': 'Good view in the morning'}
# {'target': 1, 'texts': 'Beauty sky and many seller. But no lamp overthere.  Exactly the lamp is off'}
# {'target': 1, 'texts': 'Good place to jogging with family. Kenjeran Beach with Java Sea view'}
# {'target': 1, 'texts': 'Good place to get your body healthy'}
# {'target': 1, 'texts': 'Legendary  jossssssssss'}
# {'target': 1, 'texts': 'Nice cultural street for night life. A lot of eateries and live performances that goes on very late night.'}
# {'target': 1, 'texts': 'Take a walk along Jl. Tunjungan provides an unforgettable life experience.'}
# {'target': 1, 'texts': "I've been waiting for a long time why Tunjungan isn't made into an icon, a hangout place  finally starting in 2020 someone is making it happen"}
# {'target': 1, 'texts': 'thank you, the city of Surabaya is getting more hits, the cooler we are grateful to live here, good luck in our own city, and become a safe and prosperous city Surabaya Forever'}
# {'target': 1, 'texts': "nice, really classic here. It's good if you come at night"}
# {'target': 1, 'texts': 'Very romantic'}
# {'target': 1, 'texts': 'came here because there was an EDEN CROFFLE at that time  the taste was good, the price was 15k and you got 2 large'}
# {'target': 1, 'texts': 'Jl Tunjungan then and now is different, more slang'}
# {'target': 1, 'texts': 'Public spaces are fun for all people to hang out with, from young people to veterans  awesome, fun and full of history  Love Surabaya'}
# {'target': 1, 'texts': 'The angkringan is cheap'}
# {'target': 1, 'texts': 'Suitable for enjoying the existing atmosphere'}
# {'target': 1, 'texts': "It's fun to walk while taking pictures. While hanging out sipping a hot cappuccino."}
# {'target': 1, 'texts': 'One of the streets that became an icon in the city of Surabaya'}
# {'target': 1, 'texts': "The environment is beautiful plus security is d'best"}
# {'target': 1, 'texts': 'Nice for walking'}
# {'target': 1, 'texts': 'instagramable'}
# {'target': 0, 'texts': "The buskers weren't coordinated  after one came, another one came  even though there were alre"}
# {'target': 1, 'texts': 'Good for photo spots'}
# {'target': 1, 'texts': 'I dared to post photos from an off-the-beaten angles'}
# {'target': 1, 'texts': 'Many times hear the popilarity of taman bungkul but just now have time to visit here.'}
# {'target': 1, 'texts': 'I visited here 3 years ago, maybe it has changed a lot now.'}
# {'target': 1, 'texts': 'The best place to do some exercising, Especially In the weekends.'}
# {'target': 1, 'texts': 'I found it bit crowded. Market also nearby. Good place to roam around'}
# {'target': 1, 'texts': "In my opinion, the park encompasses of skateboard arena, playground, huge empty field (shown below for events) and lots of small vendors selling street food and children's toys."}
# {'target': 1, 'texts': 'This is a very well known park in Surabaya, even people from outside Surabaya knows a little about this park. A playground for children also available here.'}
# {'target': 1, 'texts': 'Amazing place for local citizens to spend their weekend with family. lots of people gather here to just chill and meet with their community'}
# {'target': 1, 'texts': 'Nice and historic park. There is cementary of Ki Ageng and culinary ie Rawon Kalkulator'}
# {'target': 1, 'texts': 'A nice public space which is developed by surabaya government.'}
# {'target': 1, 'texts': 'One of the best city park in Indonesia, world even. It won an award and has nice playground for kids.'}
# {'target': 1, 'texts': 'Taman Bungkul is the best garden in Surabaya.'}
# {'target': 1, 'texts': 'Really love this place The "car free day event" every sunday is a must visit, you can find anything from traditional foods to nice clothings with affordable prices.'}
# {'target': 1, 'texts': 'Good place to hangout with family while enjoying the night of Surabaya. This park is quite complete.'}
# {'target': 1, 'texts': "a good place for gathering and maybe to enjoy some food there or just hanging out to chill, the park is crowded there's a skateboard track there so be careful and watch ur kid if u go there"}
# {'target': 1, 'texts': 'First time in Taman Bungkul, car free day and a lot of locals who come for exercise or enjoy snack that you can find everywhre.'}
# {'target': 1, 'texts': 'nice place to hang out.  lots of food and drink. IN'}
# {'target': 1, 'texts': 'Chill place, good for evening or morning walk.'}
# {'target': 1, 'texts': 'a good place to exercise nearby and buy some goods,'}
# {'target': 1, 'texts': 'The road under the bridge looks like it has not been maintained, the color has become plain, there is no shelter anymore'}
# {'target': 1, 'texts': "It's pretty clean & not too hot, because there are lots of trees, lots of culinary & various kinds of knick-knacks sold here"}
# {'target': 1, 'texts': 'Entrance tickets can be purchased online or on the spot (on location).'}
# {'target': 1, 'texts': 'Good  More and more facilities'}
# {'target': 1, 'texts': 'Decent place for holidays with family or friends, lots of culinary menu choices.'}
# {'target': 1, 'texts': 'An inexpensive recreation area, a variety of culinary delights and a center for souvenirs.'}
# {'target': 1, 'texts': 'Relax, but cleanliness needs to be improved'}
# {'target': 1, 'texts': 'Recommended, Those who want a Murmer vacation'}
# {'target': 1, 'texts': 'Recreational places are cheap and affordable'}
# {'target': 1, 'texts': "The place is nice  Now it's clean, plus there is a new bridge, it's even more beautiful"}
# {'target': 1, 'texts': 'Nice place'}
# {'target': 1, 'texts': 'Complete place'}
# {'target': 1, 'texts': 'Just normal'}
# {'target': 1, 'texts': 'Old Kenjeran Beach is now a better, cleaner and more comfortable place to gather with family or friends, the ticket prices are also affordable'}
# {'target': 1, 'texts': "now it's pretty good and neat"}
# {'target': 1, 'texts': 'Many Good Beach Cracker Traders Suitable For Holidays Or Just Come Here'}
# {'target': 1, 'texts': 'Super more comfortable now though'}
# {'target': 1, 'texts': 'Folk beach tourism'}
# {'target': 1, 'texts': 'Nice bridge to see the view'}
# {'target': 1, 'texts': 'The place is quite crowded, clean, MSMEs are very functioning, service   traders are good and friendly'}
# {'target': 0, 'texts': 'The Alun-alun Museum is also closed.'}
# {'target': 1, 'texts': 'Complete facilities, there is a mosque, underground parking, there is a canteen,'}
# {'target': 1, 'texts': 'There are viral photos of events in Indonesia.'}
# {'target': 1, 'texts': "There is a martyr's mosque and the courtyard is quite wide."}
# {'target': 1, 'texts': 'There is a fountain, a library.'}
# {'target': 1, 'texts': 'Thank you local government of Surabaya.'}
# {'target': 1, 'texts': "But please, for access to the library, it's best to register, don't be too complicated with this data, so that many people come there."}
# {'target': 1, 'texts': "There is a free museum underground, and it's very comfy after walking around the building above"}
# {'target': 1, 'texts': "What's a shame is the directions to the exact location on the wrong bridge should have gone to the right instead, to the left,"}
# {'target': 1, 'texts': 'Please pay attention to the city government.'}
# {'target': 1, 'texts': 'Htm free cm byr parking only 5k'}
# {'target': 1, 'texts': 'Can get on a boat too'}
# {'target': 1, 'texts': "The place is really wide  If it's during the day, don't forget to bring an umbrella"}
# {'target': 1, 'texts': "there is a playground even though it's small, there are ducks, lots of gazebos and seats, really suitable for toddlers to seniors,"}
# {'target': 1, 'texts': 'We will see views of the shady mangrove forest since entering this ecotourism area.'}
# {'target': 1, 'texts': 'Aesthetic location settings and wooden bridges that are a shame if they are not captured on camera.'}
# {'target': 1, 'texts': 'Holidays to the\xa0Mangrove\xa0Mount Anyar Tourism can be done on weekends.'}
# {'target': 1, 'texts': 'If visiting hours are about to run out, the officer will notify you via loudspeaker.'}
# {'target': 1, 'texts': 'This tourist spot is open every day from 07.00 to 15.00 WIB. Visitors are asked to maintain cleanliness and facilities during the tour.'}
# {'target': 1, 'texts': 'Some of the facilities at this tourist spot include a parking area, toilets, prayer room, gazebo, food court and other facilities that can support activities while in the Gunung Anyar Mangrove.'}
# {'target': 1, 'texts': 'The latest is the MSME showroom which will later sell food and beverages made from mangrove plants, including: mangrove syrup, mangrove chili sauce, etc.'}
# {'target': 1, 'texts': 'Even though there are still a lot of additional facilities, such as parking lots for 4-wheeled vehicles.'}
# {'target': 1, 'texts': 'Several photo spots that spoil the eye are also available almost along the route.'}
# {'target': 1, 'texts': 'Carrying the concept of Ecogreen tourism, it is very comfortable to visit for family tourism or for photo hunting or jogging around the mangrove area.'}
# {'target': 1, 'texts': 'Generally tourists travel on weekends and sometimes there are also community activities or managers who invite tourists to plant mangroves on certain dates.'}
# {'target': 1, 'texts': 'Supporting facilities include jogging tracks, trash bins in every corner, clean toilets, prayer room, photo spots, nursery, motorbike and car parking is very wide. In addition, there is also a canteen   cafeteria.'}
# {'target': 1, 'texts': "There's nothing wrong with enjoying a holiday and a picnic here. Have a great adventure"}
# {'target': 1, 'texts': 'Although there are some spots that need to be addressed again. Perfect for holidays with family or friends.'}
# {'target': 1, 'texts': 'You will see a beautiful view of the mangrove forest from the moment you enter the\xa0Mangrove\xa0Mount Anyar Tourism area. When crossing the bridge, you will be surrounded by lush mangrove trees.'}
# {'target': 1, 'texts': 'You will also be treated to views of cranes, long-tailed monkeys and sea frogs.'}
# {'target': 0, 'texts': 'but places to sit just to rest are lacking almost nonexistent.'}
# {'target': 0, 'texts': 'For crossing access to the next park (playground) why is it closed.'}
# {'target': 0, 'texts': 'So for the playground you have to go through a road that is damaged and very muddy and you have to pay for park'}
# {'target': 0, 'texts': "Kenjeran's writings were damaged, and many public chair facilities were damaged"}
# {'target': 0, 'texts': 'Annoyed by sales people who always come even though they are just passing by'}
# {'target': 0, 'texts': 'Please pay attention to the maintenance even though on holidays it is full of visitors'}
# {'target': 0, 'texts': "No need to worry if you don't bring a mat, because food beverage sellers also offer mat rental for free but with the condition that you have to order food drinks."}
# {'target': 1, 'texts': "Don't worry too about the price of food drink because the price of food drink is also listed on the menu offered."}
# {'target': 1, 'texts': 'For food and drink prices are still relatively reasonable.'}
# {'target': 1, 'texts': 'For hygiene conditions, it is much cleaner now than before the renovation.'}
# {'target': 1, 'texts': 'There are also several places for the bathroom.'}
# {'target': 1, 'texts': 'For those who want to buy souvenirs, there is also a souvenir market'}
# {'target': 1, 'texts': 'Children love to play in the sand on the beach'}
# {'target': 0, 'texts': "it's a shame the sea water is a bit cloudy."}
# {'target': 1, 'texts': 'Those who want a Murmer vacation you can take your own ass  Suitable for a big family picnic But if you want to take a boat, pay another 10k  just kiss it.'}
# {'target': 1, 'texts': 'thank you for being allowed to enter for the public'}
# {'target': 1, 'texts': 'My gosh how it has changed. Lots of temple etc, felt like in Thailand. Kudos to the people who manage it'}
# {'target': 1, 'texts': 'Many passengers are waiting to board the ship.'}
# {'target': 1, 'texts': 'Keep spirit sis'}
# {'target': 1, 'texts': 'Reduce the beauty of its old buildings.'}
# {'target': 1, 'texts': "please maintain decency, don't be too crowded because it is still inhabited, many villagers pass by"}
# {'target': 0, 'texts': 'many are damaged like the iron bars'}
# {'target': 0, 'texts': 'but my advice is not to go there at night'}
# {'target': 1, 'texts': 'but quite iconic and has the feel of the old city .'}
# {'target': 1, 'texts': 'is quite good for photography lovers to be creative and beautiful photo art'}
# {'target': 1, 'texts': 'Owned by the city government of Surabaya'}
# {'target': 1, 'texts': 'There are lots of games for children too'}
# {'target': 1, 'texts': 'Just right for relaxing'}
# {'target': 0, 'texts': 'for motorbike parking is rather difficult'}
# {'target': 0, 'texts': 'parking is a bit difficult'}
# {'target': 0, 'texts': 'Nothing to see.'}
# {'target': 0, 'texts': 'Came here after seeing the high scores on maps.'}
# {'target': 0, 'texts': "But it's just overrated."}
# {'target': 0, 'texts': 'The hype about the place is stunning inaccurate'}
# {'target': 0, 'texts': 'Waste of time unless you are going on a Gerry.'}
# {'target': 0, 'texts': 'You can get a grab car to drop you off but not to pickup'}
# {'target': 1, 'texts': 'people are welcoming'}
# {'target': 1, 'texts': 'such a bad thing'}
# {'target': 1, 'texts': "it's expensive, it's not tasty and you don't intend to sell it"}
# {'target': 1, 'texts': "the food is random, the stalls selling don't pay attention to quality"}
# {'target': 1, 'texts': "it's not worth the price, an average of 20-30 thousand for food and snacks"}
# {'target': 1, 'texts': 'really not recommended'}
# {'target': 1, 'texts': 'A very memorable experience, enjoying the hustle and bustle of a densely packed city, even at night. If you go to Surabaya, you will come here again.'}
# {'target': 1, 'texts': 'The beautiful city lights give the impression of a city that never sleeps.'}
# {'target': 1, 'texts': 'Good place to bring yoir childern, so many toys and some playing ground for free'}
# {'target': 1, 'texts': 'I felt comfortable when I sat alone here in the evening, watched group of people doing their activities, until a salesperson came to offer something.'}
# {'target': 1, 'texts': 'there are a lot of Snacks and beverages in the area. there are religious traditional spot.'}
# {'target': 1, 'texts': 'Overall is good For hanging out with your friends and family. not really Much of a Attraction Tour Point, But a Really Good Place to Chill Out and Shares some stories. But there are minimum spaces with Roof above, so be careful when It is Rainy season.'}
# {'target': 1, 'texts': "Was only here for a short time, so I couldn't tell much. The local snacks was pretty good and affordable."}
# {'target': 0, 'texts': "Kenjeran's writings were damaged, and many public chair facilities were damaged"}
# {'target': 0, 'texts': 'Annoyed by sales people who always come even though they are just passing by'}
# {'target': 0, 'texts': 'Please pay attention to the maintenance even though on holidays it is full of visitors'}
# {'target': 1, 'texts': 'Have been here 3x, 2x before the pandemic & most recently in the middle of May 2023, always happy here because basically I like to see animals & feed them.'}
# {'target': 1, 'texts': 'The place is actually nice and cool'}
# {'target': 0, 'texts': 'lots of birds, but the place looks dirty, lots of bird droppings'}
# {'target': 1, 'texts': "Cool and very beautiful. But it's a shame it's quite empty of visitors, tickets per person can be exchanged for ice cream."}
# {'target': 0, 'texts': 'Access to here is not very smooth road'}
# {'target': 0, 'texts': 'Supporting facilities such as information about Latin animal names are minimal'}
# {'target': 1, 'texts': 'yesterday after coming here, the location is quite looking for it. just follow the maps, you will find it.'}
# {'target': 0, 'texts': 'It seems deserted where the play area is closed, the condition is not well maintained since the effects of the pandemic'}
# {'target': 1, 'texts': "Good, friendly staff.  But it's still quite ok"}
# {'target': 1, 'texts': 'This place is pretty good too to visit. On weekdays, the entrance ticket is 35 thousand. To get to this place there is no public transportation, you can take an online taxi but the wait is a bit long.'}
# {'target': 0, 'texts': "It's not as interesting as it used to be, tickets are expensive, but the tours that are presented are not well maintained, the birds are few."}
# {'target': 0, 'texts': 'Poor birds'}
# {'target': 1, 'texts': 'Cool'}
# {'target': 1, 'texts': 'Interesting place, staying managed again is more interesting'}
# {'target': 1, 'texts': "There are many birds, but it's a shame that only small birds are"}
# {'target': 1, 'texts': 'Lembang tourism is really good, it is recommended to take children here to refresh'}
# {'target': 1, 'texts': 'The place is cool'}
# {'target': 1, 'texts': "It's great to have a vacation"}
# {'target': 1, 'texts': 'Good place for kids ,'}
# {'target': 1, 'texts': 'The place is good, educational for children'}
# {'target': 1, 'texts': 'Very large places, but not too many people visit this place, maybe because pandemic n mudik season.'}
# {'target': 0, 'texts': 'Not maintained well probably because of the pandemic.'}
# {'target': 1, 'texts': 'If you are happy with taking photos, then this place is highly recommended,'}
# {'target': 1, 'texts': 'Inside the rabbit town is many spot photo.'}
# {'target': 1, 'texts': 'This place is more suitable for you who want to take selfie than for children.'}
# {'target': 0, 'texts': 'I was so dissapointed after visiting this place.'}
# {'target': 1, 'texts': 'If you are looking for a place to take photos and selfie, you can put this on your list. This is very suitable for teenagers, youngsters and those who love taking selfies.'}
# {'target': 1, 'texts': 'Family tourist with animal sight seeing. There is 25k admission where you can redeem with food and drinks. Overall is not bad for tourist looking for family spot.'}
# {'target': 1, 'texts': 'Ideal for selfie lovers out there. Just try to avoid weekends, so full and packed, you won’t be able to take a proper selfie. There are cafes and food stalls inside.'}
# {'target': 0, 'texts': "I came here when it was almost dark, so I couldn't take photos in outdoor spots"}
# {'target': 0, 'texts': 'The place is still on development though most of it are completed.'}
# {'target': 0, 'texts': 'Let\'s put aside the "plagiarized" claim that has been echoing this place.'}
# {'target': 0, 'texts': 'The entrance fee is higher than my cholesterol and every attraction inside will ask you for more money.'}
# {'target': 1, 'texts': 'Fun place to spend time with family and friends.'}
# {'target': 1, 'texts': 'Its a mix of indoor and outdoor playing ground, lots of places to take good selfies, and a lot of animals that you can also feed by buying some of the foods there.'}
# {'target': 1, 'texts': 'tempat bermain anak-anak, foto - foto instagramable.'}
# {'target': 1, 'texts': 'It is  nice  but felt very pretentious. There are several places for selfie'}
# {'target': 1, 'texts': 'People who likes to take selfies would love this place. So many photo spots here. Dont ever go here alone, you will need a photographer for yourself'}
# {'target': 0, 'texts': 'this place is not well maintain, dust everywhere.'}
# {'target': 1, 'texts': 'One stop amusement park, family friendly and everybody is happy.'}
# {'target': 1, 'texts': 'Good place to take your kids but the way to get there is a bit difficult and has lots of traffic.'}
# {'target': 1, 'texts': 'The place is refreshing and the concept is good'}
# {'target': 1, 'texts': 'Doing activities outdoors is so nice but needy to remain not suitable for the golden age plus if not wara work cars.'}
# {'target': 1, 'texts': 'We had a blast at dago dreampark The staff were suuuupppeeerrr nice Highly recommend coming here during the mornings so there aren’t many people.'}
# {'target': 0, 'texts': 'I DO NOT RECOMMEND THIS PLACE FOR FOREIGNERS.'}
# {'target': 1, 'texts': 'This place is start to rising up after pandemic effect.'}
# {'target': 1, 'texts': 'The place is incredibly great with really exotic scenery'}
# {'target': 1, 'texts': 'Great place for kids activities, came here early morning, fresh air was so nice.  Dont think have grab gocar option from here to city, i rented a car.'}
# {'target': 0, 'texts': "Ticketing system was terrible and only catered to small sections of the park per booth (each games' tickets are purchased separately, no bundle tickets)."}
# {'target': 1, 'texts': "It's an okay place for refreshing despite the entrance cost for 40k"}
# {'target': 1, 'texts': 'Really maintained very well, you can have a great fun'}
# {'target': 1, 'texts': 'This place are quite nice for relaxing and refreshing'}
# {'target': 1, 'texts': 'Large, natural, landscape-shaped theme park.'}
# {'target': 1, 'texts': 'Went here with my family and it was a nice choise btw.'}
# {'target': 0, 'texts': 'Not suggested for walk along elderly unless you rent a car or drive your private car here'}
# {'target': 1, 'texts': "100% family fun  outdoor entertainment, nature's best scenery and great way to burn calories"}
# {'target': 1, 'texts': 'We visited on weekday, so all the park was for ourselves It was great.'}
# {'target': 1, 'texts': 'Love it  If you looking for nature environment here is the place'}
# {'target': 0, 'texts': 'Another instagram prank'}
# {'target': 1, 'texts': 'Great place when you go here make sure your camera or your phone is good to take pict.'}
# {'target': 1, 'texts': 'cute place that super worth to visit if you love lord of the ring.'}
# {'target': 1, 'texts': 'Unforgettable experience.'}
# {'target': 1, 'texts': 'Good for kids experiences'}
# {'target': 1, 'texts': 'New icon in North Bandung,  instagramable,  many unique spot and beautiful view with fresh air'}
# {'target': 1, 'texts': 'The one recommended place for sightseeing in north bandung'}
# {'target': 1, 'texts': 'Love place'}
# {'target': 1, 'texts': 'Superb place to satisfy your instagram needs.'}
# {'target': 1, 'texts': 'Beautiful place to spent time with family and friends. It open at 8am & close at 10pm.'}
# {'target': 1, 'texts': 'Lovely place  So much fun Many good spot to take pictures'}
# {'target': 1, 'texts': 'Pretty impressive with Hobbit looks alike village'}
# {'target': 1, 'texts': 'Welcome to the new adventures.'}
# {'target': 0, 'texts': 'Just another inmitations .well if u hav nothing much to do, just dropby.'}
# {'target': 1, 'texts': 'You can take pictures every side. All of them are beautiful. Your family will love it.'}
# {'target': 1, 'texts': 'A place to take some photos with set looks like Hobbit. You need to pay 20k to enter after paying 25k to enter Farmhouse'}
# {'target': 1, 'texts': 'Ok'}
# {'target': 1, 'texts': 'Nice place yet can be more organized, especially parking lot.'}
# {'target': 1, 'texts': 'Just so so little attraction with so many photo spots'}
# {'target': 1, 'texts': 'Just like NZ'}
# {'target': 1, 'texts': 'Love this place'}
# {'target': 1, 'texts': 'Having Fun'}
# {'target': 1, 'texts': 'good place'}
# {'target': 1, 'texts': "It's a great place in lembang, bandung, west java"}
# {'target': 1, 'texts': 'Nice place to spend time with family'}
# {'target': 1, 'texts': 'So beautiful place.'}
# {'target': 1, 'texts': 'Nice photo spot'}
# {'target': 1, 'texts': 'Nice place to be visited'}
# {'target': 1, 'texts': 'Good place'}
# {'target': 1, 'texts': 'Recomnded place'}
# {'target': 1, 'texts': 'Located in the Lembang farm house where family tours can take photos and petting small amimal.'}
# {'target': 1, 'texts': 'Tourist attractions are suitable for families, as well as children can get to know pets such as rabbits etc  the place is cool, comfortable'}
# {'target': 1, 'texts': "It's cool to take photos with your family on April 25, 2023, the ticket price is 30 thousand, but they are offered a new ride, a 6-row slide, so the ticket is 55 thousand"}
# {'target': 1, 'texts': 'The place is comfortable and beautiful, the arrangement is good with minimal land. Ticket price 20 rb already got milk pie.'}
# {'target': 1, 'texts': 'A recreation area that presents a variety of charms of natural beauty combined with modern knick-knacks.'}
# {'target': 1, 'texts': 'It is in the Lembang Milk Farmhouse.'}
# {'target': 1, 'texts': 'The concept is very good for family activities and children, there is a petting zoo where children can interact directly with fauna such as doba, iguana, cow, rabbit etc.'}
# {'target': 1, 'texts': 'A good and complete tourist spot  there are animals   flowers   interesting photo spots'}
# {'target': 1, 'texts': 'The design of the place is made of wood and is made like the house of the dwarves and is intended for taking photos,'}
# {'target': 1, 'texts': 'Honestly it was beautiful place and have beautiful scenery and fresh air.'}
# {'target': 1, 'texts': 'Hidden gem in west Bandung. Cheap entrance fee. Fresh air and nice view.'}
# {'target': 1, 'texts': 'Feel the Sensasion of Stone Age here. Safe for children to hike.'}
# {'target': 1, 'texts': 'You know this is the hidden gem of bandung barat'}
# {'target': 1, 'texts': 'Nice view, nice landscape.'}
# {'target': 1, 'texts': 'So mesmerize, great view Located on padalarang area.'}
# {'target': 1, 'texts': 'Beautiful geopark with plenty of spots for taking pictures.'}
# {'target': 0, 'texts': "4 stars because of the views and the fact that you don't have to travel too far away from the city to experience a feeling of space."}
# {'target': 0, 'texts': 'You have to do a little hiking to get to the top from the parking area.'}
# {'target': 1, 'texts': "A great place if you're in the mood to hike with friends or family."}
# {'target': 1, 'texts': 'Good scenery and there are a lot of spot for photography and also good for you who want to take a foto for your prewedding foto session.'}
# {'target': 1, 'texts': 'This place has a beautiful view and certainly instagramable. It can even be used as a pre-wedding photo place.'}
# {'target': 1, 'texts': 'You will love this place if you love trekking, feeling the breeze on your face, and sight seeing from the top of the hill.'}
# {'target': 1, 'texts': 'I highly recommended to go to this destination.'}
# {'target': 1, 'texts': 'Visit on August 2019. Entrance fee 8.000 for each person. The place is good for family gathering. But watchout for kids.'}
# {'target': 1, 'texts': 'Beautiful scenery yet we need an effort to climb and you gotta be careful because there are many big vehicles along the way.'}
# {'target': 1, 'texts': 'Beautiful “hidden” place'}
# {'target': 1, 'texts': 'Thanks to the stone garden and all the attractions in the limestone mountains, such as Mount Hawu, Pawon Cave, and the managers of both the local residents and the rock climbing community of Masigit Mountains, who have made a good contribution to West Java tourism.'}
# {'target': 1, 'texts': 'Great geopark, beautiful karst, trace fossil, outdoor activities, try to climb to puncak  panyawangan then see the beautiful landscape around there,'}
# {'target': 0, 'texts': 'Not a big place,'}
# {'target': 1, 'texts': 'cool rocky hill for selfie. It took at least 3 hours to be there, because a lot of cool spots. who take children, should be noted because many sharp stones.'}
# {'target': 1, 'texts': 'Natural & full of adventure.  No need to book hammock service,  they are always available there.'}
# {'target': 1, 'texts': 'Best place to see  sunset  beautiful thousand of stones  in the early morning there is a lot of monkey long tail  I went rhere for the sunrise  I arrived at 5 am'}
# {'target': 1, 'texts': 'I was getting another experience by tracking this stone hill. And finally, my tired journey was worthy paid at the top.'}
# {'target': 1, 'texts': 'Natural stone arrange by nature'}
# {'target': 1, 'texts': '37 million years ago this area was ocean. There was a cave below this area it was called pawon cave.'}
# {'target': 1, 'texts': 'One of Geopark in Kabupaten Bandung, closed at 5 PM.'}
# {'target': 1, 'texts': 'Better come verr early or late afternoon'}
# {'target': 1, 'texts': 'finally come to this place,. great rocky view from highland  entry gate village 10K  entry ticket 8K  parking 7K'}
# {'target': 1, 'texts': 'Cant make it to the place'}
# {'target': 0, 'texts': 'The bird keeper is violence to birds, especially the blue macaw keeper.'}
# {'target': 0, 'texts': 'Poor birds 💔'}
# {'target': 0, 'texts': 'Too expensive if weekend not worth it'}
# {'target': 0, 'texts': "Isn't bird suppose to fly freely?"}
# {'target': 0, 'texts': 'Not operational'}
# {'target': 1, 'texts': 'Nice place'}
# {'target': 0, 'texts': "It's not being maintained right now, it's cramped and small, the guard above who showed the parrots is also ignorant"}
# {'target': 0, 'texts': 'The suffering of the animals, the cages that are too small, the birds in chains'}
# {'target': 0, 'texts': 'dissapointed'}
# {'target': 0, 'texts': 'Disappointed yesterday, I came a long way there,'}
# {'target': 0, 'texts': 'Sudden inspection of cluster construction that has been stalled for 3 years  just the foundation'}
# {'target': 0, 'texts': 'The cages are not taken care of and the bird pavilion staff are not polite'}
# {'target': 0, 'texts': 'Closed for now (ppkm)'}
# {'target': 0, 'texts': 'Not worth the visit, the entry ticket is expensive.'}
# {'target': 0, 'texts': 'Not satisfied, because there was no bird show, even though we came from Surabaya.'}
# {'target': 0, 'texts': 'It smells and is small, and the prices are high. It is not worth the visit'}
# {'target': 0, 'texts': 'not updating'}
# {'target': 0, 'texts': 'The birds collection is not completed yet,'}
# {'target': 0, 'texts': 'Just a small place'}
# {'target': 0, 'texts': "It's not as interesting as it used to be, tickets are expensive,"}
# {'target': 0, 'texts': 'The location is still in a housing complex. The situation is not maintained.'}
# {'target': 0, 'texts': 'Last time I was here, the atmosphere was not well maintained.'}
# {'target': 0, 'texts': 'Coming the second time was quite disappointing, where a lot of birds were trimmed because there was a construction project for townhouses,'}
# {'target': 0, 'texts': "The ticket price is too expensive inside B, there's no wow at all, if you want to take a photo with a bird, you have to have food, you can buy it at the entrance,"}
# {'target': 0, 'texts': 'Tourist attractions are far from the city  . the entrance fee is 50 thousand per person'}
# {'target': 0, 'texts': "At first, it was open, okay, now it's declining, the food just has mattress threads"}
# {'target': 0, 'texts': "It's fun to feed the birds"}
# {'target': 0, 'texts': 'The entrance fee is higher than my cholesterol and every attraction inside will ask you for more money.'}
# {'target': 0, 'texts': 'Entrance fee 60k per person with food. Run down , not maintaining well.'}
# {'target': 0, 'texts': 'There is only a small place with couple of low maintenance rabbit.'}
# {'target': 1, 'texts': 'The place is quite nice, many spots to take a pic for instagram.'}
# {'target': 0, 'texts': 'Why they still post under the name Rabbit Town when there is no rabbit at all'}
# {'target': 0, 'texts': 'Amazingly waste of time to visit'}
# {'target': 0, 'texts': 'Bought food for entrance tickect. The food taste was horrible.'}
# {'target': 0, 'texts': 'overpriced and overrated.'}
# {'target': 0, 'texts': 'I already know this is a shameless ripoff that gave birth to “selfie tourism” so my expectations is pretty low.'}
# {'target': 0, 'texts': 'Foodcourt payment system is awkward and not completely ready,'}
# {'target': 0, 'texts': 'This “selfie tour” museum just plagiarized the work of other well known artists around the world for their own monetary gain'}
# ...
# {'target': 0, 'texts': 'the gardener is not takeing care about the flowers much'}
# {'target': 0, 'texts': 'the buildings are not renovated, toilet is not clean'}
# {'target': 0, 'texts': 'Absolutely fo not recommend!!!'}
# {'target': 0, 'texts': 'Not a good experience'}
# {'target': 0, 'texts': 'Absolutely horrible, do not waste your time and money going to this place'}
# {'target': 0, 'texts': 'they will try to sell you overpriced stuff we wanted to be nice and help as we were told the place was ruined by the pandemic'}
# {'target': 0, 'texts': 'she forced us to go to an atm we said our cards didn’t work and she still wanted to force our driver to pay for us so we can pay him later'}
# {'target': 0, 'texts': 'What a horrible situation. Avoid that place if you can!'}
# {'target': 0, 'texts': 'The tour was too short because there are some ladies at the entrance who pick-up every tourist and show you the place but they rushes you just to visit their shop'}
# {'target': 0, 'texts': 'I was really dissappointed.'}
# {'target': 0, 'texts': 'Most facilities are not maintained even some shops are broken by falling tree trunks.'}
# {'target': 0, 'texts': 'Would avoid this place very run down'}
# {'target': 0, 'texts': 'Empty place, almost all the shops closed, the monkeys are fighting among themselves'}
# {'target': 0, 'texts': 'Neglected place, a guide accompanies you and then takes you to his store to buy'}
# {'target': 0, 'texts': "It's not worth going."}
# {'target': 0, 'texts': 'Really upsetting experience'}
# {'target': 0, 'texts': '. I felt very very uncomfortable immediately just due to that.'}
# {'target': 0, 'texts': 'It was a misery place'}
# {'target': 0, 'texts': 'I got bitten by a monkey there.'}
# {'target': 0, 'texts': 'the guide did not warn us about the danger of a bite'}
# {'target': 0, 'texts': 'As others mentioned, at the end, the guides lock you in their shop to buy extremely overpriced souvenirs'}
# {'target': 0, 'texts': 'Small place with guide that does not speak English very well'}
# {'target': 0, 'texts': 'Very boring place.Nothing much to see.'}
# {'target': 0, 'texts': 'My passanger got cheat here.'}
# {'target': 0, 'texts': 'they will try to sell everything with crazy price'}
# {'target': 0, 'texts': "This place is a disaster, wouldn't go anywhere near it again."}
# {'target': 0, 'texts': 'I had a terrible experience'}
# {'target': 0, 'texts': 'In one word, they are heartless.'}
# {'target': 0, 'texts': ', I cannot recommend this resort due to the lack of proper customer service and flexibility with cancellations'}
# {'target': 0, 'texts': 'ITS FAR FROM ANY TOURISTIC PLACE'}
# {'target': 0, 'texts': 'No decent supermarket in the area'}
# {'target': 0, 'texts': 'it doesnt look like in the pictures'}
# {'target': 0, 'texts': 'MAJOR insects problems'}
# {'target': 0, 'texts': 'i don’t find it safe regarding things'}
# {'target': 0, 'texts': 'Security employees are not polite'}
# {'target': 0, 'texts': 'Very disappointing visit! Very commercialized temple.'}
# {'target': 0, 'texts': 'The worst was probably the animal abuse called a petting zoo'}
# {'target': 0, 'texts': 'Very very disappointing and would not recommend it!'}
# {'target': 0, 'texts': 'Definitely not worth the drive, time and money!'}
# {'target': 0, 'texts': 'just pass by this place - it doesn’t worse money and time'}
# {'target': 0, 'texts': 'and this terrible toilets inside for extra money'}
# {'target': 0, 'texts': 'Animal abuse, awfully ugly park, absolutely not worth the tour'}
# {'target': 0, 'texts': 'The place is crowded with ugly tourist restaurants that make the place terrible with awful and loud music'}
# {'target': 0, 'texts': 'This place is not worth coming, adding that it is far away from a lot of things that are way better.'}
# {'target': 0, 'texts': 'Hordes of local tourists taking insta photo and 75K entry. Felt inauthentic. Bad experience.'}
# {'target': 0, 'texts': 'Too busy with nothing to see but tacky scenery.'}
# {'target': 0, 'texts': "Don't go. It is a tourist trap!"}
# {'target': 0, 'texts': 'Tourist trap!'}
# {'target': 0, 'texts': 'Sadly, not a good expierence of'}
# {'target': 0, 'texts': 'Over-commercialized place where you pay to enter then pay to take photos and use washrooms'}
# {'target': 0, 'texts': 'bad parking service.'}
# {'target': 0, 'texts': 'Nobody organizing the traffic there'}
# {'target': 0, 'texts': 'What a disappointment. Simply overcrowded,'}
# {'target': 0, 'texts': 'Not worth visiting'}
# {'target': 0, 'texts': 'No any historical information about this'}
# {'target': 0, 'texts': 'It was a mistake to go there and pay so much money'}
# {'target': 0, 'texts': 'The view is not as I expected.'}
# {'target': 0, 'texts': 'it is filled with tasteless "tourist trap" attractions and scary puppets.'}
# {'target': 0, 'texts': 'Huge tourist trap! Big disappointment!!!'}
# {'target': 0, 'texts': 'Not worth the time and effort to get there'}
# {'target': 0, 'texts': 'now the place is destroyed'}
# {'target': 0, 'texts': 'Very diasappointing. Overrun with foreign and local tourists'}
# {'target': 0, 'texts': 'Tacky statues for photos.'}
# {'target': 0, 'texts': 'The most shocking part for me were the toilets'}
# {'target': 0, 'texts': 'Imo absolutely not worth visiting'}
# {'target': 0, 'texts': 'Touristy nightmare. Skip this one'}
# {'target': 0, 'texts': "Not complaining about the price tho, but the temple isn't worth it, very small and surrounded by tourist"}
# {'target': 0, 'texts': 'Not really what I was expecting, more of a theme park.'}
# {'target': 0, 'texts': 'Would not recommend going'}
# {'target': 0, 'texts': 'and it’s truly awful how they’re keeping animals'}
# {'target': 0, 'texts': 'Horror! Tourist trap..'}
# {'target': 0, 'texts': 'terrible conditions'}
# {'target': 0, 'texts': 'The ticket is expensive and not worth'}
# {'target': 0, 'texts': 'Inside there are many enslaved animals'}
# {'target': 0, 'texts': 'Very disappointed temple, expensive for the area. Too many attractions around. Not worths it at all.'}
# {'target': 0, 'texts': 'The worst place we visited'}
# {'target': 0, 'texts': 'Looks like a big tacky playground,'}
# {'target': 0, 'texts': 'Animals kept in literally tiny spaces'}
# {'target': 0, 'texts': 'was a disgrace really! Honestly do not waste your money or support such conditions.'}
# {'target': 0, 'texts': 'They honestly looked so unwell and it was heartbreaking to see'}
# {'target': 0, 'texts': 'It really ruined my whole experience'}
# {'target': 0, 'texts': 'Tacky playground and the whole surroundings is not what you expect when you visit a temple'}
# {'target': 0, 'texts': 'One of the most disappointing places I have ever seen.'}
# {'target': 0, 'texts': 'Absolutely not recommended. Completely cluttered with tacky, bad sculptures and completely overpriced.'}
# {'target': 0, 'texts': 'I absolutely cannot understand how anyone can give this place a good rating.'}
# {'target': 0, 'texts': 'Unbelievably busy, overpriced. Plastic statues with garish colors. Does not seem authentic.'}
# {'target': 0, 'texts': 'Photo spot over rated. Nothing much'}
# {'target': 0, 'texts': 'The timings mentioned are misleading.'}
# {'target': 0, 'texts': 'is like a tacky low quality cheap looking tourist attraction! Sorry'}
# {'target': 0, 'texts': 'No water was around as the water level was very low and a lot of rubbish around.'}
# {'target': 0, 'texts': 'The temple complex is very small and does not live up to expectations'}
# {'target': 0, 'texts': 'Very crowded, far from everything'}
# {'target': 0, 'texts': 'Horrible experience'}
# {'target': 0, 'texts': 'They removed us by force without warning or explanation.'}
# {'target': 0, 'texts': 'is a horrible, nasty place'}
# {'target': 0, 'texts': 'not much to see'}
# {'target': 0, 'texts': 'Just way too busy, full of tacky'}
# {'target': 0, 'texts': 'This place has been the biggest disappointment'}
# {'target': 0, 'texts': 'What a disappointing tourist trap wasting time going there and paying to get in, I felt used.'}
# {'target': 0, 'texts': 'Absolutely useless'}
# {'target': 0, 'texts': 'Could be nice if there is no garbage'}
# {'target': 0, 'texts': 'All of these kids are throwing literally everything they eat from plastic bags'}
# {'target': 0, 'texts': 'Insanely dirty'}
# {'target': 0, 'texts': 'for parking (makes no sense) and the beach is SOOO DIRTY'}
# {'target': 0, 'texts': 'Don’t go, it’s not worth it!'}
# {'target': 0, 'texts': 'it has a disgusting amount of trash specially plastic everywhere'}
# {'target': 0, 'texts': 'Locals throwing stuff everywhere.'}
# {'target': 0, 'texts': 'Indonesia is turning in to a rip-off'}
# {'target': 0, 'texts': 'found the place completely covered with garbage'}
# {'target': 0, 'texts': "I'm very worried about the situation"}
# {'target': 0, 'texts': 'Not recommended for tourists as it charges 50k and so little to see'}
# {'target': 0, 'texts': 'Very disappointed by this place. Pricey and the park is in a poor state.'}
# {'target': 0, 'texts': 'Entrance tickets, food prices, parking are too expensive for tourist sites like this, not to mention the facilities that are not maintained'}
# {'target': 0, 'texts': 'Which in my opinion is too expensive for that'}
# {'target': 0, 'texts': 'not transparent about the price'}
# {'target': 0, 'texts': 'Frankly, we felt trapped'}
# {'target': 0, 'texts': 'Lots of carpenters'}
# {'target': 0, 'texts': 'Kind of sad, forgotten park.'}
# {'target': 0, 'texts': '50k for the entrance seemed a bit expensive.'}
# {'target': 0, 'texts': 'The museum was just faded pictures in a room'}
# {'target': 0, 'texts': 'lack of maintenance, the museum are also closed down.'}
# {'target': 0, 'texts': "Too bad it's not maintained, the stairs are slippery"}
# {'target': 0, 'texts': "Wasn't mad about it. The facility is in dire need of renovation."}
# {'target': 0, 'texts': "children's play facilities and trash cans are lacking"}
# {'target': 0, 'texts': 'very inaccessible for disabilities'}
# {'target': 0, 'texts': 'The road is not accessible for wheelchairs or canes'}
# {'target': 0, 'texts': "Guiding blocks for netra friends don't exist and most of the roads are paved"}
# {'target': 0, 'texts': 'No directions for friends who are deaf'}
# {'target': 0, 'texts': 'Not open 24 hours and the toilet is very smelly'}
# {'target': 0, 'texts': "It's a pity that the park and the large area are not managed properly."}
# {'target': 0, 'texts': 'I hope the local government will immediately follow up'}
# {'target': 0, 'texts': ', lots of them are broken, lots of seats are broken'}
# {'target': 0, 'texts': 'Many mosquitoes'}
# {'target': 0, 'texts': "mostly those who don't care about which grass should be stepped on"}
# {'target': 0, 'texts': 'So many trashes, everyone is littering, plastic bottles everywhere'}
# {'target': 0, 'texts': 'no water in musholla, hard to park vehicle, river stinks,'}
# {'target': 0, 'texts': 'transjakarta shelter nearby DOES NOT have machine for e-wallet top up and the staff doesn’t even bother'}
# {'target': 0, 'texts': 'Definitely I would never ever go to that place again'}
# {'target': 0, 'texts': 'lot a people dont know how to keep plants and garden properly'}
# {'target': 0, 'texts': 'This isn’t the right point!'}
# {'target': 0, 'texts': "Stinky and the parc isn't well maintained."}
# {'target': 0, 'texts': 'Disorganized'}
# {'target': 0, 'texts': 'I felt uncomfortable with one of the park employees'}
# {'target': 0, 'texts': 'Too crowded.'}
# {'target': 0, 'texts': 'overcrowded'}
# {'target': 0, 'texts': 'very crowded'}
# {'target': 0, 'texts': 'The driveway is narrow, the garbage is scattered'}
# {'target': 0, 'texts': 'Not comfortable for family trips'}
# {'target': 0, 'texts': 'Lawn cutting workers using machines are very annoying'}
# {'target': 0, 'texts': 'Sitting was kicked out by kang broom'}
# {'target': 0, 'texts': 'Children are vulnerable to being pushed due to crowded queues'}
# {'target': 0, 'texts': 'Lot of people not use mask but the staff or security over there dont care.'}
# {'target': 0, 'texts': 'the parking attendant is in cahoots with the helmet thief'}
# {'target': 0, 'texts': 'Nothing special there'}
# {'target': 0, 'texts': "The workers there don't speak English."}
# {'target': 0, 'texts': 'Truly horrendous'}
# {'target': 0, 'texts': 'google maps screws up going to this place'}
# {'target': 0, 'texts': 'Dead fish floating all over the place.'}
# {'target': 0, 'texts': 'Very bad smell.'}
# {'target': 0, 'texts': 'Was a big mistake to visit this place.'}
# {'target': 0, 'texts': "Cannot understand how anyone can spend it's day here."}
# {'target': 0, 'texts': 'Too expensive, food and drinks also above average sale prices'}
# {'target': 0, 'texts': 'Utterly disgusting - trash everywhere, polluted, stinking water'}
# {'target': 0, 'texts': 'due to pointlessly confusing road closures, insanely difficult to find.'}
# {'target': 0, 'texts': "Wouldn't wish it on anyone let alone recommend it."}
# {'target': 0, 'texts': 'dirty beach, not fit for playing in the water/ walking barefeet. it will make your feet itchy'}
# {'target': 0, 'texts': 'The water stinks and super crowded'}
# {'target': 0, 'texts': 'So many trash nowadays'}
# {'target': 0, 'texts': 'POOR Service'}
# {'target': 0, 'texts': 'most railways are not operational.'}
# {'target': 0, 'texts': 'Many of the tracks seem to be permanently closed or as it is called: "under maintenance".'}
# {'target': 0, 'texts': 'So once and NEVER AGAIN!'}
# {'target': 0, 'texts': 'Also everything looks run down'}
# {'target': 0, 'texts': 'Many shops and food stands also seem to be permanently closed.'}
# {'target': 0, 'texts': 'Strongly not recommended going here in peak season'}
# {'target': 0, 'texts': 'my brother just lost his cell-phone, what a very tiring day today ...what a day!!'}
# {'target': 0, 'texts': "The facility was so terrible, especially the mosque place, every roof was leaking and it didn't provide any shalat wearing stuff."}
# {'target': 0, 'texts': "The worst experience ever, tbh people just glorificate this amusement park too much, it's overrated"}
# {'target': 0, 'texts': 'The place is too crowded'}
# {'target': 0, 'texts': 'A lot of dizzy playing happen here, I do not enjoy it.'}
# {'target': 0, 'texts': 'The queeing is tasted crazy because really waste time.'}
# {'target': 0, 'texts': 'This is by far the most borring amusement park..'}
# {'target': 0, 'texts': 'Loud loop music is playing everywhere.'}
# {'target': 0, 'texts': 'Lines way too long, and no indication of the length of wait,'}
# {'target': 0, 'texts': 'employees clueless, very inefficient loading process for roller coaste'}
# {'target': 0, 'texts': 'this unpleasant experience'}
# {'target': 0, 'texts': 'the price to buy drink is so expensive'}
# {'target': 0, 'texts': 'I had a very dissapointing experience recently'}
# {'target': 0, 'texts': 'there are several playgrounds and attractions that are closed'}
# {'target': 0, 'texts': 'That being said, i just wasted Rp200.000+ for this horrible and unpleasant experience.'}
# {'target': 0, 'texts': 'Worst them park in the world'}
# {'target': 0, 'texts': 'Very underwhelming rides'}
# {'target': 0, 'texts': 'Too many people stuck at one area or waiting in one attraction.'}
# {'target': 0, 'texts': 'Some indoor rides are really dusty'}
# {'target': 0, 'texts': 'Feels like scam, pay money for nothing'}
# {'target': 0, 'texts': 'People so rude here, they queue jump, and we tell the staff, the staff don’t do anything'}
# {'target': 0, 'texts': 'Not recommended travel here'}
# {'target': 0, 'texts': "Most of the attractions look like they're falling appart"}
# {'target': 0, 'texts': 'Half of the attractions were closed'}
# {'target': 0, 'texts': 'I would suggest to avoid this place!'}
# {'target': 0, 'texts': 'Long queue'}
# {'target': 0, 'texts': 'Overated place, this place is so old.'}
# {'target': 0, 'texts': 'Very poor on the entrance gate'}
# {'target': 0, 'texts': 'Most of machines not working. Not worth for ticket price'}
# {'target': 0, 'texts': 'the system is so bad, even you have queued for 3 hours'}
# {'target': 0, 'texts': 'overcrowded and miss manage.'}
# {'target': 0, 'texts': 'the queues are longer than my will to live'}
# {'target': 0, 'texts': 'Long hour queue, and the games were partial available'}

# %% [markdown]
# ## Prepocessing Data

# %% [markdown]
# ### Make Dataframe

# %% [markdown]
# Create a dataframe from the json dataset and print head() to see the top dataset

# %%
# Membuat DataFrame contoh
df = pd.DataFrame(datastore)

# Menampilkan beberapa baris pertama DataFrame
print(df.head())
# Out:
#    target                                              texts
# 0       0         Monday, Many tours in Surabaya are closed.
# 1       1  Great Place for sightseeing and spending time ...
# 2       1  Cool place, comfortable, clean, unlike other s...
# 3       1  Place of education for the citizens of Surabay...
# 4       1                                        Really good

# %% [markdown]
# Do dataframe **info()** to see the data type, column name, null and more

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2867 entries, 0 to 2866
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  2867 non-null   int64
#  1   texts   2867 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 44.9+ KB

# %% [markdown]
# Do dataframe shape() to see the number of rows and columns

# %%
df.shape
# Out:
# (2867, 2)

# %% [markdown]
# Check for null or missing value from the dataset, make sure there are no null values

# %%
# Checking for missing values

df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Create a bar plot using seaborn to see how the values of each target compare

# %%
# Let's observe distribution of positive / negative sentiments in dataset

import seaborn as sns
sns.countplot(x='target', data=df)
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %% [markdown]
# ### Pre-training Model
#
# In this section take a sample value from the target that will be used as a reference for other values

# %%
df["texts"][2]

# You can see that our text contains punctuations, brackets, HTML tags and numbers
# We will preprocess this text in the next section
# Out:
# 'Cool place, comfortable, clean, unlike other squares, this place has a unique architecture and layout'

# %% [markdown]
# Data pre-processing using Regular Expression. Removes HTML tags: replaces anything between opening and closing <> with empty space

# %%
TAG_RE = re.compile(r'<[^>]+>')

def remove_tags(text):
    '''Removes HTML tags: replaces anything between opening and closing <> with empty space'''

    return TAG_RE.sub('', text)

# %% [markdown]
# Use the nltk library to download stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Install emoji and re

# %%
# !pip install emoji
import emoji
import re
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.5.0.tar.gz (355 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 355.8/355.8 kB 20.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.5.0-py2.py3-none-any.whl size=351211 sha256=38ec36c7279606b2714a99f5baf2ff9f64c3a46889b56b8bcbd978c3dc3ec5d3
#   Stored in directory: /root/.cache/pip/wheels/2a/0c/2c/07b5af72b120503fe24590691d24c462a25e5e530db8700a96
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.5.0

# %% [markdown]
# Process the data to remove unnecessary characters and emoji

# %%
def preprocess_text(sen):
    '''Cleans text data up, leaving only 2 or more char long non-stepwords composed of A-Z & a-z only
    in lowercase'''

    sentence = sen.lower()

    # Remove html tags
    sentence = remove_tags(sentence)

    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)  # When we remove apostrophe from the word "Mark's", the apostrophe is replaced by an empty space. Hence, we are left with single character "s" that we are removing here.

    # Remove Stopwords
    pattern = re.compile(r'\b(' + r'|'.join(stopwords.words('english')) + r')\b\s*')
    sentence = pattern.sub('', sentence)

    # Menghapus emoji
    esentence = emoji.demojize(sentence)
    sentence = re.sub(r':[^:]+:', '', sentence)

    # Menghapus semua tanda baca
    sentence = re.sub(r'[.,?!()=*+\-&]', ' ', sentence)

    # Remove multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)  # Next, we remove all the single characters and replace it by a space which creates multiple spaces in our text. Finally, we remove the multiple spaces from our text as well.

    return sentence

# %% [markdown]
# Calling preprocessing_text function on destination_reviews with the code below

# %%
# Calling preprocessing_text function on destination_reviews

X = []
sentences = list(df['texts'])
for sen in sentences:
    X.append(preprocess_text(sen))

# %% [markdown]
# Print the target value to ensure that the sample is completely clean

# %%
# Sample cleaned up

X

# As we shall use Word Embeddings, stemming/lemmatization is not performed as a preprocessing step here
# Out:
# ['monday many tours surabaya closed ',
#  'great place sightseeing spending time friends family',
#  'cool place comfortable clean unlike squares place unique architecture layout',
#  'place education citizens surabaya particular society general ',
#  'really good',
#  'lots good smooth',
#  'clean well maintained bright cool',
#  'suroboyo children creative activity center always well maintained municipal government surabaya',
#  'several times first time smoke fountain appears yeeaay',
#  'good familyable',
#  'unique',
#  'surabaya icon exciting',
#  'surabaya residents must come take part activities every weekend namely creative home training',
#  'place nice could icon surabaya ',
#  'first time turned good compared jakarta pay different enter art museum free parking also free wow',
#  'cozy atmosphere gallery',
#  'really good',
#  'many good spots take pictures make memories surabaya',
#  'really crowded nighttime go ',
#  'highly recommended holding event balai pemuda even though air super hot outside sby ',
#  'place comfortable',
#  'many spot enjoy jogging track viewpoint water cycle boat trip take see mangrove ecosystem',
#  'server yet',
#  'mangrove tours near house really suitable end month come family',
#  'place nice perfect refreshing mind moment construction already underway facilities quite adequate problem access driveway still construction',
#  'location still well maintained even though many spots still lot explore far wonorejo mangroves',
#  'clean good area',
#  'free entry pay parking nice place lots photo spots',
#  'new mountain mangrove tour rungkut surabaya',
#  'cool',
#  'natural beautiful better come early morning ',
#  'great means learning science especially mangrove forest ecosystems',
#  'cheap tourist attractions complete ',
#  'place comfortable relieve fatigue stress better come morning evening hot day really hot',
#  'mount anyar mangrove forest looking cool free tourist attractions surabaya solution ',
#  'cool',
#  'place nice comfortable clean recommended family tourism',
#  'mangroves one roads badly damaged mud thok go back cat finally mangroves road paved jogging track wide take moment parking thousand toilet also',
#  'mantab clean cheap free travel',
#  'free nature tourism pays parking fees quite complete child friendly facilities ',
#  'beautiful beautiful cool ',
#  'nice beautiful suitable roads',
#  'place cool comfortable clean lots places sit tired walking road wide recommended thin healing',
#  'looking cool free tourist spots surabaya gunung anyar mangrove forest solution destination ecotourism concept located jalan medokan sawah medokan ayu village rungkut district gunung anyar tambak gunung anyar ',
#  'cool place outskirts metropolis',
#  'nice clean good photo spots',
#  'great trees well cared ',
#  'make garden beautiful',
#  'many sports facilities damaged',
#  'okay',
#  'choice light hangout destination kids afternoon',
#  'wow siipp',
#  'bad place relax eating toast ',
#  'park children play facilities futsal basketball courts swings slides several sports equipment reflection stones park clean bad playing children across delicious meatballs reog meatballs',
#  'nice place clean mind',
#  'attractive',
#  'road bridge looks like maintained color become plain shelter anymore',
#  'pretty clean hot lots trees lots culinary various kinds knick knacks sold clothes also available even though many visitors',
#  'entrance tickets purchased online spot location ',
#  'good facilities',
#  'decent place holidays family friends lots culinary menu choices ',
#  'inexpensive recreation area variety culinary delights center souvenirs ',
#  'relax cleanliness needs improved',
#  'recommended',
#  'recreational places cheap affordable',
#  'place nice clean plus new bridge even beautiful',
#  'nice place',
#  'complete place',
#  'normal',
#  'old kenjeran beach better cleaner comfortable place gather family friends ticket prices also affordable',
#  'pretty good neat',
#  'many good beach cracker traders suitable holidays come ',
#  'super comfortable though',
#  'folk beach tourism',
#  'nice bridge see view',
#  'place clean msmes functioning service traders good friendly',
#  'worth ',
#  'nice place edge kenjeran beach',
#  'good scenery',
#  'big pagoda wide sea view',
#  'enter via park gate per person place clean people good',
#  'nice place take pictures',
#  'crowded full many people ',
#  'beautiful goddess mercy statue surabaya ',
#  'last time went kenjeran place like yonks ago im still like prep ',
#  'budha temple great place',
#  'keren love ',
#  'good',
#  'beautiful place enjoy island madura ferry boat',
#  'stitches neat good',
#  'busiest port always operating hours',
#  'nice atmosphere hot day',
#  'nice',
#  'good place spend time take pictures',
#  'sea view good',
#  'expensive view match expectations',
#  'bad hanging chatting',
#  'nothing ',
#  'shop exist fake aliases ',
#  'less organized',
#  'dirty',
#  'small alleyway okay industrial old building photography theme nothing else ',
#  'many old buildings cultural heritage every saturday sunday many people visit jalan gula spot photo',
#  'good photos end sugar road rubber road ',
#  'good used many murals clear ',
#  'really recommended',
#  'creepy old houses',
#  'anymore',
#  'good photo spots right left old building ',
#  'crowded well maintained ',
#  'interesting place instagrammable photo location',
#  'bad vintage photo',
#  'actually good photo spot ',
#  'bad remembering old times ',
#  'place alley long ',
#  'old city surabaya area lots ancient buildings',
#  'normal come photo',
#  'children love play park',
#  'atmosphere cool middle scorching heat surabaya',
#  'clean comfortable suitable sports playing',
#  'excellent',
#  'one green open spaces',
#  'less parking input',
#  'fun life partner',
#  'satisfactor',
#  'good park clean quite spacious',
#  'quick tidy',
#  'nyesell tired taking train',
#  'enough refresh kids place small middle city',
#  'recommended',
#  'suitable accompanying children play',
#  'clean enough park staff also friendly',
#  'clean good playground park surabaya ',
#  'place minimal turned beautiful park quite complete facilities makes people want visit next day',
#  'many improvements side playground park ',
#  'place besides delivering small children play quite lot games place bored relaxed morning evening ',
#  'legen sold across street tastes pretty good ingredients delicious snacks also cheap ',
#  'beer surabaya',
#  'place comfortable night running community gathering',
#  'great selfies',
#  'come picture match real one futsal field',
#  'lack synthetic grass futsal field heavily damaged',
#  'parking attendants everywhere stop everywhere told pay critical ',
#  'many street vendors small',
#  'lot people',
#  'parking lot expensive',
#  'slow service',
#  'bad urine odor',
#  'impressive beautiful',
#  'messy place',
#  'less members',
#  'dirty',
#  'bad place sure',
#  'transportation difficult foreigners ',
#  'need get taxi good luck ',
#  'nothing see foods taste bad price expensive ',
#  'tourist destination seriously nothing see eat ',
#  'public rubbish everywhere ',
#  'place messed place',
#  'dirty less sign',
#  'got scammed ',
#  'ok',
#  'humiliate ',
#  'polluted poor wifi dirty',
#  'nope',
#  'wrong open closed time',
#  'expectations',
#  'bad facility',
#  'bad service',
#  'nothing really',
#  'horrible',
#  'buy food drinks ',
#  'recommended ',
#  'nice place',
#  'god sipp',
#  'casting baramundi also payus place spacious cak baygon friendly hilarious delicious coffee shop motorbike parking safe best',
#  'cool spot fishing cheap fish much josssss',
#  'cheapest daily fishing thousand fish great',
#  'daily fishing spots surabaya area relatively cheap eits forget bring umbrella okay',
#  'htm patient gelem tree must big fish',
#  'cheap fishing spots wide areas free bait milkfish tilapia dominant fish afraid heat bring umbrella',
#  'pretty big fish still curious satisfied results',
#  'think good fishing try go ',
#  'shame fish cruising eat',
#  'beloved pond lur cheap cheerful shop old fish big',
#  'pond wide suitable fish farming',
#  'gut test spot',
#  'bad bite',
#  'good place buy snacks needs vitamin sea ',
#  'love bridge especially horrible pandemic force people quarantine cool gorgeous view vehicles surrounding ',
#  'nice place see sun rise know view fountain night gone night ',
#  'nice place afternoon stroll taje picture see suramadu bridge place ',
#  'good place family vacay enjoying view beach kenjeran',
#  'stop cycling',
#  'could park parking far away walk quite far reach centre bridge',
#  'bridge beautiful landscape ',
#  'wonderful',
#  'bridge closed vehicle afternoon locals use attraction watch strong crosswind ',
#  'nice place visit especially sun sets beautiful ',
#  'looking great night many beautiful lights surabaya bridge',
#  'place refresh mind',
#  'nice place hanging around various street food waiting visitors',
#  'could see bridge kenjeran lama park also beautiful sunrise moment',
#  'good view morning',
#  'beauty sky many seller lamp overthere exactly lamp ',
#  'good place jogging family kenjeran beach java sea view',
#  'good place get body healthy',
#  'legendary jossssssssss',
#  'nice cultural street night life lot eateries live performances goes late night ',
#  'take walk along jl tunjungan provides unforgettable life experience ',
#  'waiting long time tunjungan made icon hangout place finally starting someone making happen',
#  'thank city surabaya getting hits cooler grateful live good luck city become safe prosperous city surabaya forever',
#  'nice really classic good come night',
#  'romantic',
#  'came eden croffle time taste good price got large',
#  'jl tunjungan different slang',
#  'public spaces fun people hang young people veterans awesome fun full history love surabaya',
#  'angkringan cheap',
#  'suitable enjoying existing atmosphere',
#  'fun walk taking pictures hanging sipping hot cappuccino ',
#  'one streets became icon city surabaya',
#  'environment beautiful plus security best',
#  'nice walking',
#  'instagramable',
#  'buskers coordinated one came another one came even though alre',
#  'good photo spots',
#  'dared post photos beaten angles',
#  'many times hear popilarity taman bungkul time visit ',
#  'visited years ago maybe changed lot ',
#  'best place exercising especially weekends ',
#  'found bit crowded market also nearby good place roam around',
#  'opinion park encompasses skateboard arena playground huge empty field shown events lots small vendors selling street food children toys ',
#  'well known park surabaya even people outside surabaya knows little park playground children also available ',
#  'amazing place local citizens spend weekend family lots people gather chill meet community',
#  'nice historic park cementary ki ageng culinary ie rawon kalkulator',
#  'nice public space developed surabaya government ',
#  'one best city park indonesia world even award nice playground kids ',
#  'taman bungkul best garden surabaya ',
#  'really love place car free day event every sunday must visit find anything traditional foods nice clothings affordable prices ',
#  'good place hangout family enjoying night surabaya park quite complete ',
#  'good place gathering maybe enjoy food hanging chill park crowded skateboard track careful watch ur kid go ',
#  'first time taman bungkul car free day lot locals come exercise enjoy snack find everywhre ',
#  'nice place hang lots food drink ',
#  'chill place good evening morning walk ',
#  'good place exercise nearby buy goods ',
#  'road bridge looks like maintained color become plain shelter anymore',
#  'pretty clean hot lots trees lots culinary various kinds knick knacks sold ',
#  'entrance tickets purchased online spot location ',
#  'good facilities',
#  'decent place holidays family friends lots culinary menu choices ',
#  'inexpensive recreation area variety culinary delights center souvenirs ',
#  'relax cleanliness needs improved',
#  'recommended want murmer vacation',
#  'recreational places cheap affordable',
#  'place nice clean plus new bridge even beautiful',
#  'nice place',
#  'complete place',
#  'normal',
#  'old kenjeran beach better cleaner comfortable place gather family friends ticket prices also affordable',
#  'pretty good neat',
#  'many good beach cracker traders suitable holidays come ',
#  'super comfortable though',
#  'folk beach tourism',
#  'nice bridge see view',
#  'place quite crowded clean msmes functioning service traders good friendly',
#  'alun alun museum also closed ',
#  'complete facilities mosque underground parking canteen ',
#  'viral photos events indonesia ',
#  'martyr mosque courtyard quite wide ',
#  'fountain library ',
#  'thank local government surabaya ',
#  'please access library best register complicated data many people come ',
#  'free museum underground comfy walking around building ',
#  'shame directions exact location wrong bridge gone right instead left ',
#  'please pay attention city government ',
#  'htm free cm byr parking k',
#  'get boat ',
#  'place really wide day forget bring umbrella',
#  'playground even though small ducks lots gazebos seats really suitable toddlers seniors ',
#  'see views shady mangrove forest since entering ecotourism area ',
#  'aesthetic location settings wooden bridges shame captured camera ',
#  'holidays mangrove mount anyar tourism done weekends ',
#  'visiting hours run officer notify via loudspeaker ',
#  'tourist spot open every day wib visitors asked maintain cleanliness facilities tour ',
#  'facilities tourist spot include parking area toilets prayer room gazebo food court facilities support activities gunung anyar mangrove ',
#  'latest msme showroom later sell food beverages made mangrove plants including mangrove syrup mangrove chili sauce etc ',
#  'even though still lot additional facilities parking lots wheeled vehicles ',
#  'several photo spots spoil eye also available almost along route ',
#  'carrying concept ecogreen tourism comfortable visit family tourism photo hunting jogging around mangrove area ',
#  'generally tourists travel weekends sometimes also community activities managers invite tourists plant mangroves certain dates ',
#  'supporting facilities include jogging tracks trash bins every corner clean toilets prayer room photo spots nursery motorbike car parking wide addition also canteen cafeteria ',
#  'nothing wrong enjoying holiday picnic great adventure',
#  'although spots need addressed perfect holidays family friends ',
#  'see beautiful view mangrove forest moment enter mangrove mount anyar tourism area crossing bridge surrounded lush mangrove trees ',
#  'also treated views cranes long tailed monkeys sea frogs ',
#  'places sit rest lacking almost nonexistent ',
#  'crossing access next park playground closed ',
#  'playground go road damaged muddy pay park',
#  'kenjeran writings damaged many public chair facilities damaged',
#  'annoyed sales people always come even though passing ',
#  'please pay attention maintenance even though holidays full visitors',
#  'need worry bring mat food beverage sellers also offer mat rental free condition order food drinks ',
#  'worry price food drink price food drink also listed menu offered ',
#  'food drink prices still relatively reasonable ',
#  'hygiene conditions much cleaner renovation ',
#  'also several places bathroom ',
#  'want buy souvenirs also souvenir market',
#  'children love play sand beach',
#  'shame sea water bit cloudy ',
#  'want murmer vacation take ass suitable big family picnic want take boat pay another kiss ',
#  'thank allowed enter public',
#  'gosh changed lots temple etc felt like thailand kudos people manage ',
#  'many passengers waiting board ship ',
#  'keep spirit sis',
#  'reduce beauty old buildings ',
#  'please maintain decency crowded still inhabited many villagers pass ',
#  'many damaged like iron bars',
#  'advice go night',
#  'quite iconic feel old city ',
#  'quite good photography lovers creative beautiful photo art',
#  'owned city government surabaya',
#  'lots games children ',
#  'right relaxing',
#  'motorbike parking rather difficult',
#  'parking bit difficult',
#  'nothing see ',
#  'came seeing high scores maps ',
#  'overrated ',
#  'hype place stunning inaccurate',
#  'waste time unless going gerry ',
#  'get grab car drop pickup',
#  'people welcoming',
#  'bad thing',
#  'expensive tasty intend sell ',
#  'food random stalls selling pay attention quality',
#  'worth price average thousand food snacks',
#  'really recommended',
#  'memorable experience enjoying hustle bustle densely packed city even night go surabaya come ',
#  'beautiful city lights give impression city never sleeps ',
#  'good place bring yoir childern many toys playing ground free',
#  'felt comfortable sat alone evening watched group people activities salesperson came offer something ',
#  'lot snacks beverages area religious traditional spot ',
#  'overall good hanging friends family really much attraction tour point really good place chill shares stories minimum spaces roof careful rainy season ',
#  'short time tell much local snacks pretty good affordable ',
#  'kenjeran writings damaged many public chair facilities damaged',
#  'annoyed sales people always come even though passing ',
#  'please pay attention maintenance even though holidays full visitors',
#  'x pandemic recently middle may always happy basically like see animals feed ',
#  'place actually nice cool',
#  'lots birds place looks dirty lots bird droppings',
#  'cool beautiful shame quite empty visitors tickets per person exchanged ice cream ',
#  'access smooth road',
#  'supporting facilities information latin animal names minimal',
#  'yesterday coming location quite looking follow maps find ',
#  'seems deserted play area closed condition well maintained since effects pandemic',
#  'good friendly staff still quite ok',
#  'place pretty good visit weekdays entrance ticket thousand get place public transportation take online taxi wait bit long ',
#  'interesting used tickets expensive tours presented well maintained birds ',
#  'poor birds',
#  'cool',
#  'interesting place staying managed interesting',
#  'many birds shame small birds ',
#  'lembang tourism really good recommended take children refresh',
#  'place cool',
#  'great vacation',
#  'good place kids ',
#  'place good educational children',
#  'large places many people visit place maybe pandemic mudik season ',
#  'maintained well probably pandemic ',
#  'happy taking photos place highly recommended ',
#  'inside rabbit town many spot photo ',
#  'place suitable want take selfie children ',
#  'dissapointed visiting place ',
#  'looking place take photos selfie put list suitable teenagers youngsters love taking selfies ',
#  'family tourist animal sight seeing admission redeem food drinks overall bad tourist looking family spot ',
#  'ideal selfie lovers try avoid weekends full packed able take proper selfie cafes food stalls inside ',
#  'came almost dark take photos outdoor spots',
#  'place still development though completed ',
#  'let put aside plagiarized claim echoing place ',
#  'entrance fee higher cholesterol every attraction inside ask money ',
#  'fun place spend time family friends ',
#  'mix indoor outdoor playing ground lots places take good selfies lot animals also feed buying foods ',
#  'tempat bermain anak anak foto foto instagramable ',
#  'nice felt pretentious several places selfie',
#  'people likes take selfies would love place many photo spots dont ever go alone need photographer ',
#  'place well maintain dust everywhere ',
#  'one stop amusement park family friendly everybody happy ',
#  'good place take kids way get bit difficult lots traffic ',
#  'place refreshing concept good',
#  'activities outdoors nice needy remain suitable golden age plus wara work cars ',
#  'blast dago dreampark staff suuuupppeeerrr nice highly recommend coming mornings many people ',
#  'recommend place foreigners ',
#  'place start rising pandemic effect ',
#  'place incredibly great really exotic scenery',
#  'great place kids activities came early morning fresh air nice dont think grab gocar option city rented car ',
#  'ticketing system terrible catered small sections park per booth games tickets purchased separately bundle tickets ',
#  'okay place refreshing despite entrance cost k',
#  'really maintained well great fun',
#  'place quite nice relaxing refreshing',
#  'large natural landscape shaped theme park ',
#  'went family nice choise btw ',
#  'suggested walk along elderly unless rent car drive private car ',
#  ' family fun outdoor entertainment nature best scenery great way burn calories',
#  'visited weekday park great ',
#  'love looking nature environment place',
#  'another instagram prank',
#  'great place go make sure camera phone good take pict ',
#  'cute place super worth visit love lord ring ',
#  'unforgettable experience ',
#  'good kids experiences',
#  'new icon north bandung instagramable many unique spot beautiful view fresh air',
#  'one recommended place sightseeing north bandung',
#  'love place',
#  'superb place satisfy instagram needs ',
#  'beautiful place spent time family friends open close pm ',
#  'lovely place much fun many good spot take pictures',
#  'pretty impressive hobbit looks alike village',
#  'welcome new adventures ',
#  'another inmitations well hav nothing much dropby ',
#  'take pictures every side beautiful family love ',
#  'place take photos set looks like hobbit need pay enter paying enter farmhouse',
#  'ok',
#  'nice place yet organized especially parking lot ',
#  'little attraction many photo spots',
#  'like nz',
#  'love place',
#  'fun',
#  'good place',
#  'great place lembang bandung west java',
#  'nice place spend time family',
#  'beautiful place ',
#  'nice photo spot',
#  'nice place visited',
#  'good place',
#  'recomnded place',
#  'located lembang farm house family tours take photos petting small amimal ',
#  'tourist attractions suitable families well children get know pets rabbits etc place cool comfortable',
#  'cool take photos family april ticket price thousand offered new ride row slide ticket thousand',
#  'place comfortable beautiful arrangement good minimal land ticket price rb already got milk pie ',
#  'recreation area presents variety charms natural beauty combined modern knick knacks ',
#  'lembang milk farmhouse ',
#  'concept good family activities children petting zoo children interact directly fauna doba iguana cow rabbit etc ',
#  'good complete tourist spot animals flowers interesting photo spots',
#  'design place made wood made like house dwarves intended taking photos ',
#  'honestly beautiful place beautiful scenery fresh air ',
#  'hidden gem west bandung cheap entrance fee fresh air nice view ',
#  'feel sensasion stone age safe children hike ',
#  'know hidden gem bandung barat',
#  'nice view nice landscape ',
#  'mesmerize great view located padalarang area ',
#  'beautiful geopark plenty spots taking pictures ',
#  ' stars views fact travel far away city experience feeling space ',
#  'little hiking get top parking area ',
#  'great place mood hike friends family ',
#  'good scenery lot spot photography also good want take foto prewedding foto session ',
#  'place beautiful view certainly instagramable even used pre wedding photo place ',
#  'love place love trekking feeling breeze face sight seeing top hill ',
#  'highly recommended go destination ',
#  'visit august entrance fee person place good family gathering watchout kids ',
#  'beautiful scenery yet need effort climb gotta careful many big vehicles along way ',
#  'beautiful hidden place',
#  'thanks stone garden attractions limestone mountains mount hawu pawon cave managers local residents rock climbing community masigit mountains made good contribution west java tourism ',
#  'great geopark beautiful karst trace fossil outdoor activities try climb puncak panyawangan see beautiful landscape around ',
#  'big place ',
#  'cool rocky hill selfie took least hours lot cool spots take children noted many sharp stones ',
#  'natural full adventure need book hammock service always available ',
#  'best place see sunset beautiful thousand stones early morning lot monkey long tail went rhere sunrise arrived ',
#  'getting another experience tracking stone hill finally tired journey worthy paid top ',
#  'natural stone arrange nature',
#  ' million years ago area ocean cave area called pawon cave ',
#  'one geopark kabupaten bandung closed pm ',
#  'better come verr early late afternoon',
#  'finally come place great rocky view highland entry gate village entry ticket parking k',
#  'cant make place',
#  'bird keeper violence birds especially blue macaw keeper ',
#  'poor birds ',
#  'expensive weekend worth ',
#  'bird suppose fly freely ',
#  'operational',
#  'nice place',
#  'maintained right cramped small guard showed parrots also ignorant',
#  'suffering animals cages small birds chains',
#  'dissapointed',
#  'disappointed yesterday came long way ',
#  'sudden inspection cluster construction stalled years foundation',
#  'cages taken care bird pavilion staff polite',
#  'closed ppkm ',
#  'worth visit entry ticket expensive ',
#  'satisfied bird show even though came surabaya ',
#  'smells small prices high worth visit',
#  'updating',
#  'birds collection completed yet ',
#  'small place',
#  'interesting used tickets expensive ',
#  'location still housing complex situation maintained ',
#  'last time atmosphere well maintained ',
#  'coming second time quite disappointing lot birds trimmed construction project townhouses ',
#  'ticket price expensive inside wow want take photo bird food buy entrance ',
#  'tourist attractions far city entrance fee thousand per person',
#  'first open okay declining food mattress threads',
#  'fun feed birds',
#  'entrance fee higher cholesterol every attraction inside ask money ',
#  'entrance fee per person food run maintaining well ',
#  'small place couple low maintenance rabbit ',
#  'place quite nice many spots take pic instagram ',
#  'still post name rabbit town rabbit ',
#  'amazingly waste time visit',
#  'bought food entrance tickect food taste horrible ',
#  'overpriced overrated ',
#  'already know shameless ripoff gave birth selfie tourism expectations pretty low ',
#  'foodcourt payment system awkward completely ready ',
#  'selfie tour museum plagiarized work well known artists around world monetary gain',
#  'really bad place spend money charges rp entry place see rabbits pet shop free ',
#  'tourist go ',
#  'shame say place complete rip places museums la county museum art museum ice cream ',
#  'plagiarism encouraged unique place narcissists insecure people take selfies ',
#  'animals overweight given many food space move around ',
#  'really appreciate plagiarism give good rating encouragement ',
#  'paid go around ',
#  'recommended ',
#  'tourist trap many rip art installations around world without permit artist shame ',
#  'recommended hang nice place clean except monkey cages stinky',
#  'fake fake fake ',
#  'deluded copycat copying others work arts stupid ',
#  'selfie tourism full plagiarised artworks',
#  'little bit pricy photos worth recommended',
#  'small chamber selfy expensive price bandung ',
#  'worst payment system ever ready open yet',
#  'recommend place foreigners ',
#  'small place',
#  'interesting used tickets expensive ',
#  'location still housing complex situation maintained ',
#  'last time atmosphere well maintained ',
#  'coming second time quite disappointing lot birds trimmed construction project townhouses ',
#  'ticket price expensive inside wow want take photo bird food buy entrance ',
#  'tourist attractions far city entrance fee thousand per person',
#  'first open okay declining food mattress threads',
#  'fun feed birds',
#  'entrance fee higher cholesterol every attraction inside ask money ',
#  'entrance fee per person food run maintaining well ',
#  'small place couple low maintenance rabbit ',
#  'place quite nice many spots take pic instagram ',
#  'overall really worthed',
#  'still post name rabbit town rabbit ',
#  'amazingly waste time visit',
#  'bought food entrance tickect food taste horrible ',
#  'overpriced overrated ',
#  'already know shameless ripoff gave birth selfie tourism expectations pretty low ',
#  'foodcourt payment system awkward completely ready ',
#  'selfie tour museum plagiarized work well known artists around world monetary gain',
#  'really bad place spend money charges rp entry place see rabbits pet shop free ',
#  'tourist go ',
#  'want see sticker room take money enter ',
#  'shame say place complete rip places museums la county museum art museum ice cream ',
#  'plagiarism encouraged unique place narcissists insecure people take selfies ',
#  'animals overweight given many food space move around ',
#  'really needed animal maintenance',
#  'really appreciate plagiarism give good rating encouragement ',
#  'paid go around ',
#  'recommended ',
#  'tourist trap many rip art installations around world without permit artist shame ',
#  'recommended hang nice place clean except monkey cages stinky',
#  'fake fake fake ',
#  'deluded copycat copying others work arts stupid ',
#  'selfie tourism full plagiarised artworks',
#  'little bit pricy photos worth recommended',
#  'small chamber selfy expensive price bandung ',
#  'worst payment system ever ready open yet',
#  'recommend place foreigners ',
#  'worst park ever saw bandung area inside area road going deep absolutely nothing see',
#  'impressed theme park built mountain side ',
#  'first really shocked ticket sooooo cheap person ',
#  'really really poor even say terrible management ',
#  'one security named edih friend abusing cat',
#  'wish set price access every photo spot ',
#  'untidy smelly place',
#  'truly expectations staff friendly playing area also sucks ',
#  'well maintained rides old ',
#  'place really bad services ',
#  'really dissapointing excepted ',
#  'sorry place absolutely worth price ',
#  'lousy place ',
#  'worn old place ',
#  'really interesting',
#  'place took hrs per trip bandung city area due bad traffic around dago dec ',
#  'worth visit see interesting point interest',
#  'actually place lot great potential spend lot momey satisfied attraction ',
#  'worth visit ',
#  'looks like zombie dead abandoned forest every game station person charge guide tourists e flying fox yet still collecting ticket charge go ',
#  'recommend place',
#  'make road place crowded jammed made local people difficult go around fact nothing significant place',
#  'worth visit everything pay inside ',
#  'good take pictures',
#  'dreampark nightmare ',
#  'place worth ',
#  'bad traffic ',
#  'unfortunately abandoned place ',
#  'access road heavy traffic terrible',
#  'small place mass place holiday',
#  'recommended ',
#  'first pale comparison years ago',
#  'experience fun actually beautiful environment enjoy ',
#  'nothing much see worth money another place see animal cruelty',
#  'crowded weekend place cramped convenient ',
#  'maybe local bandung see anything special ',
#  'would give stars place reason lembang even congested ',
#  'small nothing exciting',
#  'like way animals treated instance calves ',
#  'photos shared facebook overrated small crowded place',
#  'expect want show instagram get like much want despite wasting time sacrificed ',
#  'calfs incredibly skinny severely malnourished ',
#  'buy vegetable outside veg allowed feed animal guess cannot bring sheep',
#  'good place ',
#  'pay almost everything ',
#  'nothing special thought farms ',
#  'overrated instagrammable place ',
#  'nothing taking picture wearing boring costume ',
#  'plugs traffic open people starts line since since built main route bandung lembang blocks whole route makes big ugly traffic jam ',
#  'warning may farmhouse searching hating place ',
#  'inform ticket redeem restaurant long spend minimum k',
#  'go holiday season able enjoy scenery flower ',
#  'western style many people selfies local culture found ',
#  'place taking selfy photos furthermore road nearby become extremely traffic place ',
#  'security harmfull ',
#  'wasting time suitable narsistic wannabe person stupid person come twice overpromised place ',
#  'hard find parking area ',
#  'poor bad parking management atm debit accepted cash',
#  'good impression better spend time around',
#  'touristy money oriented cafe need pay entrance fee give cashback meals worth ',
#  'food tasty clearly sell ambience food ',
#  'wrong point map hard find',
#  'try eat fried rice already expensive taste super bad ',
#  'place photos increasingly eroding nature go cafe must pay htm food cafes even worth price ',
#  'stop htm even want eat cafe entrance ticket ',
#  'shame toilets muddy',
#  'typical tourist spot puts photo seekers first ',
#  'ok place take pictures ',
#  'cool modern place ',
#  'really bad order drink takes hour wait service really lacking ',
#  'old service satisfactory',
#  'okay tour okay send also polite ',
#  'mosque rd floor difficult reach elderly parents',
#  'health protocols lacking ',
#  'price expensive',
#  'direction shown goggle map misleading unclear making difficult tourists outside area find ',
#  'please update path getting lost direction wrong ended going strange place cliff ',
#  'far away jakarta punclut kicked told go back reason west java people haddehhh',
#  'yet google map gives way moment really confusing end work',
#  'times came back find place wrong google map point right',
#  'direction comes go directed payment ',
#  'know google maps wrong place closed work',
#  'pkok suitable traveling',
#  'every place pay',
#  'late get stuck gate hours',
#  'infrastructure safe comfortable bring ',
#  'disappointing place',
#  'reached location yet coordinates wrong',
#  'trap fake location ',
#  'colorful dancing fountain middle pond part asia africa park newly public park eastern bandung city plays three times daily evening ',
#  'place play family comfortable quite safe',
#  'fountain beautiful',
#  'less informative service commercial ',
#  'cool fountain',
#  'recommended place comfortable suitable taking family',
#  'one show minutes',
#  'comfortable',
#  'cool',
#  'fountain dances beautifully',
#  'make happy',
#  ' card required want enter eventhough parent came accompany children ',
#  'find stupid pay entrance fee accompany young yet top value next time',
#  'want take photo ship area buy food minimum payment per person',
#  'protocol patch ',
#  'buy tickets line book buy online ',
#  'take kids snow park queue long happen sob',
#  'children toys quite complete ',
#  'families enter attitude security good fostered ',
#  'place small games currently snow park ',
#  'prokes entered well',
#  'playing field complete like game master ',
#  'parking attendant comfortable responsible changing money',
#  'waiting line hours play half hour ',
#  'operationally ready queue cut customers way difficult enter ',
#  'car park spacious result get parking ',
#  'really bad queue long like trap buy cards people',
#  'poor service came way told go home car park',
#  'play snow even though one happen wednesday october ',
#  'place dingy dirty maintained go chapter ',
#  'year old child enters joy fun including companion',
#  'critical fraud rates displayed match child crying screaming ',
#  'place organized',
#  'nice place',
#  'narrow parking',
#  'queue badly irregular',
#  'please make management pay attention things disappoint visitors ',
#  'sooooooo cold',
#  'restaurant hard find',
#  'good',
#  'disappointing ',
#  'slowtttt',
#  'disappointing',
#  'ticket expensive especially weekends size actually small even though photo looks big',
#  'valet parking service good',
#  'place rides really good services shop keepers bad order fried rice hours',
#  'small parking lot instead valet system thousand additional parking goes adjoining housing',
#  'sense empathy employees disappointing come back ',
#  'food canteen expensive noodle pop ',
#  'comfortable security service firm manager complains answers satisfy visitors point comfortable',
#  'even though game master foank snow park',
#  'place layout already good ',
#  'place nice',
#  'ordering food served well long expensive service also bitchy thank ',
#  'recommended rule bring food outside employees ready rule ',
#  'miin get neighbors hear noise every day son still baby never take good nap always hears screams really sad house comfortable',
#  'said bring food want eat restaurant wear dry clothes first even though hungry swimming want swim ',
#  'cafe expensive match price ',
#  'bathroom rinse water also strange room rinse water even small droplets',
#  'really recommendation',
#  'recommended uncomfortable allowed prohibited people understand ',
#  'feel disappointed paid lot money ',
#  'join home marketing office villa cafe outside bird pavillon ',
#  'parking attendant direct parking attendant payment post',
#  'ticket prices bit expensive see birds',
#  'fun able give bird food ',
#  'pay even though play parking lot minutes',
#  'buy bird food feed birds pigeons lovebirds parrots parrots owls turkeys chickens guinea pigs otters etc',
#  'cashier bought jutek card female employee white waiting line ticket smiled said sorry long wait ',
#  'playing children must really fun ',
#  'maybe due last pandemic birds used like eat served manager give ',
#  'staffs friendly kind really show kindness bandung people ',
#  'food bad ',
#  'dont charge entrance fee anymore ',
#  'playground dirty back place',
#  'maintain well dirty monkey rabbit look pity ',
#  'souvenir fashion store way ',
#  'ticket price one adult expensive college student idr per adult kidding ',
#  'photo spots like labyrinth many room connect ',
#  'hope manager place see hopefully respond concern mine ',
#  'jakarta person play bandung come ticket price average ',
#  'animals monkeys owls parrot rabbits well taken care ',
#  'food quality standard price expensive ',
#  'parking ideal since renovating parking space prepared ',
#  'actually place sells instagramable spot',
#  'need pay entrance ticket required buy food drink menu per person comes',
#  'fyi coffee lover good coffee',
#  'think want visit enjoy palm sugar coffee forgot name menu ',
#  'still affordable ',
#  'first special actually nothing special place area strategic enough parking area small ',
#  'entrance fee rp person pay extra entrance fee attraction room ',
#  'mean yes expensive',
#  'second thank god came friday morning crowded ',
#  'one thing also bothering time hilarious rabbits ',
#  'good place love selfie problem spending money enter factory outlet shop',
#  'many fun spots take selfie taking pictures together place sure gives excitement ',
#  'also quite lot stairs careful bring elderly people ',
#  'rabbit house good rabbits',
#  'feels pricey course opinion pay almost every facilities activities want know free nothing special ',
#  'remain using drone photos many trees stuck ',
#  'overall nice good',
#  'place huge easily got lost cause signs clear please put clearer signs ',
#  'make free old people ride car inside area shouldnt pay k',
#  'maybe improve mermaid area bottom really dirty ',
#  'first theres lot mini hidden costs incurred us ',
#  'cannot explain package well imagine going atv ride one round ',
#  'cant speak english expect us understand complicated way conduct business ',
#  'please god sake staff speak english disclose alllll costs may occur make decisions come ',
#  'worth mark words',
#  'love fresh air atmosphere nature sound cicadas well river ',
#  'unfortunately explore rain ',
#  'slippery path hamper journey ',
#  'sun entire place loveable ',
#  'come spouse place good dating unique photospot ',
#  'change ticket soft drinks entrance tickets replace mini cute cactu',
#  'first come inside parks find lot option choose kinds arena best ',
#  'provide based age weight family gathering etc',
#  'nice food court ',
#  'unfortunately got serve good management ',
#  'even though early day miss communicating team clients eo dago dream park team ',
#  'ask often get missed information like ticket prices place rest age restriction peripheral restriction etc management team',
#  'fixed ',
#  'whole things still fantastic',
#  'place well maintained manicured landscapes enjoy quite close city took half hour car ride cihampelas weekend morning ',
#  'might bit challenging elders place quite terrain ',
#  'price quite affordable many kind activities riding horse ride bicycle kids atv row boat shooting flying fox etc ',
#  'enjoy view many place selfieable instagramable ',
#  'apart ok',
#  'natural surroundings pavements made easy access ',
#  'unique shaping follows nature great vacation sports ',
#  'many features facilities one best place large groups vacation ',
#  'sheltered easy walk path connects every directions helps elders people wheelchair kids especially downpour ',
#  'guard rails safety nets warning signs especially dangerous stairways steep edges almost seem missing safety first never open safety provided entirely ',
#  'make dedicated ticket booth feature park guys clerks scatter place warn help customers ',
#  'lot options bring baby ride horse give food rabbits ',
#  'although looks sickly ',
#  'highly recommended',
#  'could receive kind special card deposit something swipe enter trying locate ticket',
#  'many attractive photo place instagramable clean public toilet tissue provided restaurants parking space well arrange entrance per person charge ',
#  'european aisle quite nice',
#  'wide area cause still inside farmhouse lembang like concept place ',
#  'ticket price quite cheap family friendly located inside farm house visit place without relocating ',
#  'lot activities european style calming ambience ',
#  'recommended place family',
#  'place big know entrance fee much either ',
#  'try go peak season enjoy place fully without many crowds',
#  'also staff friendly ',
#  'enjoy fresh air',
#  'good place remember childhood feel good bring kiddos every us',
#  'yeah big green ',
#  'surrounded busy roads',
#  'well touristy spot beginning ',
#  'way might good lunch since find open air food court somewhere plot ',
#  'park really green beautiful many trees also make air become cooler ',
#  'many areas people skateboard jogging many kind sports',
#  'accessed easily located near city centre many public transportation place ',
#  'many people come many purpose rendezvous exercise looking local food play children even dating someone special ',
#  'usually crowded weekend especially car free day cfd event every sunday morning ',
#  'many beuty flower planted ',
#  'green shade first impression first sight ',
#  'one amazing beautiful garden surabaya ',
#  'love second home town ',
#  'recommended kayin fauzi owner pondok mantau producer mantau black pepper special buns balikpapan ',
#  'also lots community gathering weekend maybe could join one want ',
#  'place clean ',
#  ' overall good place relax chill',
#  'sunday morning lots sellers kinds goods trifting',
#  'nice street food found around area ',
#  'public restrooms especially men restroom bit dirty sink working ',
#  ' clothes also available even though many visitors',
#  'need worry bring mat food beverage sellers also offer mat rental free condition order food drinks',
#  'worry price food drink price food drink also listed menu offered ',
#  'also several places bathroom ',
#  'hygiene conditions much cleaner renovation ',
#  'food drink prices still relatively reasonable ',
#  'want buy souvenirs also souvenir market',
#  'shame sea water bit cloudy ',
#  'want take boat pay another k',
#  'suitable big family picnic',
#  'many visitors got lost muddy road puddles rainwater high tide',
#  'rainy season gets road really muddy ',
#  'shame road location repaired ',
#  'visit natural attraction family friends ',
#  'taking photo around premises free ',
#  'even dragon fish statue ask money ',
#  'pretty much ',
#  'went monday many visitors comfortable enough five us ',
#  'fair price ',
#  'clean toilet',
#  'poor access main road ',
#  'weekend traffic jam dago street park ',
#  'view nature recommend give try',
#  'equipment attractions regularly maintenance ',
#  'many great spot photography remember reach spot need buy ticket',
#  'minor side attraction spot need mosquito repellent due lot bugs ',
#  'advice maybe spot need ticket experience ',
#  'lot food option one resto ',
#  'recommend place everyone guys try place least ',
#  'hated system though ',
#  'take tons good photos great ambience ',
#  'think worth price ',
#  'must go attraction comfortable clean ample parking great kids',
#  'information officers sell pastries hobbit houses latest dream garden ',
#  'entering pay entrance ticket farm first thousand',
#  'first enter area required buy ticket also acts voucher exchanged glass',
#  'atmosphere cool building concept feels like indonesia ',
#  'lots food cheap',
#  'also various souvenirs sold ',
#  'many flower plants give color place ',
#  'trafic crowded road access bit sheer ',
#  'worth visit ',
#  'also make tent camp friends ',
#  'villagers friendly wanna know history place take tour guide also know best angle take many good pictures ',
#  'beware monkeys ',
#  'many good photo spot ',
#  'beautiful wide view natural huge stones around ',
#  'little climb needed promise worth ',
#  'relatively cheap need pay per person car parking ',
#  'place quite easy access',
#  'mark yet big road need see maps carefully getting closer location ',
#  'need help find best spot want know history friendly guides help ',
#  'unfortunately bad toilets restrooms ',
#  'monkeys try steal food already warned ',
#  'entrance rocky need considered management ',
#  'many cliffs extraordinary ',
#  'huge chunk limestone surrounding green hills ',
#  'use hi heels better visit afternoon sunset little hard find toilet ',
#  'bad lots trash thrown visitors ',
#  'also lot kilms limestone mines around produces smokes messed beautiful view ',
#  'quite refreshment stalls ',
#  'entrance fee parking cheap total bike rider ',
#  'easily covered vehicle ',
#  'last metres road main road quarry rough stoney track ',
#  'quite crowded weekends ',
#  'better go weekdays enjoy place completely ',
#  'good place see sunset could feel wind blows hitting stones ',
#  ' would recommend',
#  'also great place take pictures ',
#  'despite difficulties experienced view top hill mostly satifying anyone see ',
#  'beware visit rain occurs ground difficult step ',
#  'beware wild monkeys inhabits place ',
#  'one toilet ',
#  'road access go full rock carefull want come especially use motorbike ',
#  'entrance ticket idr ',
#  'come careful monkeys live ',
#  'dont reccomend place looking sunrise sun blocked mountains ',
#  'see picture video scenery really good see bandung city ',
#  'best time visit stone garden around pm depends waether',
#  'maybe long time atmosphere cafe outside also well maintained ',
#  'good place love selfie problem spending money enter factory outlet shop',
#  'recommendable come ',
#  'nursery room got light ',
#  'playground kids dirty ',
#  'definitely worth money ',
#  'cages also dirty ',
#  'scabies ',
#  'rabbit farm rabbits well maintained ',
#  'rest place selfies taking photos ',
#  'wish could improve service food ',
#  'food menu wait hour since ice stock run another hour bcs cup run ',
#  'gotta say food sadfood know mean least make platting proper price ',
#  'yes take selfies salvageable attractions came heavily edit bad disrepair ',
#  'people sense see auras house feels sad icky could feel despair felt joy got sucked soul exaggerating ',
#  'many parts many attractions broken dirty ',
#  'looks fake cheap ',
#  'clean maintained smells musty dusty ',
#  'selfie attraction complete disrepair ',
#  'pricing standard cafe price food quality awful low quality food get bulk kinds ',
#  'food overpriced price fit worth ',
#  'come ',
#  'wholly regret coming ',
#  'awful ',
#  'first review one star comment regret sooo much ever come ',
#  'manager duty place write complaint could complaint staff almost nothing reduce anger ',
#  'food awful ',
#  'monkey koi children playground really maintained atleast gave children something forget fact rabbit ',
#  'entrance ticket fee buy atleast menu per person actually ok choose directly front standing creates queue really uncomfy ',
#  'food coffee nice',
#  'seems want sell selfie places lots theme place kind old need lot reparation ',
#  'dont expect anything',
#  'worth come ',
#  'places dirty maintaned well ',
#  'definitely going ',
#  'real shame ',
#  'worst charge people want see work take photos background without giving royalty credit artist work using ',
#  'second area display replica work art without recognition whatsoever real artist ',
#  'literally nothing enjoy bunch area take selfie selfie tourism know ',
#  'however brighter side feel delighted could save roundtrip la see love lights ',
#  'room advertised closed ticket lady courtesy told us ',
#  'rabbit place literally hungry rabbits could interact feed extra handful carrot peels pieces estimates markup ',
#  'decide yayoi sued costly give stickers visitor ',
#  'many selfie spot maintained could see shoe marks paint peeling ',
#  'worst experience ever',
#  'imagine opportunity lost ridiculous payment management ',
#  'cancel orders resentment ',
#  'queue hour pay',
#  'instead creating something unique supportive arts abandoned ethics wasted great opportunity showcase indonesian artists ',
#  'visiting place hurtful local community also hurtful real artists limits visitors scope world ',
#  'worth even single cent one worst way spend money ',
#  'painted rooms take pictures cafetaria small shop spend money low quality stuff ',
#  'hell pay extra counterfeited artwork cheap scoundrel ',
#  'really worth time taking traffic jam cramped parking space eventually greeted counterfeited artwork pay extra ',
#  'goes show respect artists works ',
#  'shameful dissapointing ',
#  'clearly establishment respect works people ',
#  'say rip displays inspired blatantly copied without crediting original artist museums ',
#  'worth entry fee ',
#  'owls cute ',
#  'place clean ',
#  'wanna tell ugly truth dear netizen ',
#  'plagiarsm bootleging maybe ',
#  'come many creative people indonesia',
#  'ridiculous overprice recommended ',
#  'mean get pay every single spot ',
#  'need pay activities ',
#  'tickets per person around much see taking pictures food also nearby also ',
#  'immoral owners blatantly copying famous artworks slake people instagram ego ',
#  'wisata selfie joke',
#  'ever visit place',
#  'go back place ever ',
#  'better close ready',
#  'worth mark words',
#  'please god sake staff speak english disclose alllll costs may occur make decisions come ',
#  'cant speak english expect us understand complicated way conduct business ',
#  'cannot explain package well imagine going atv ride one round ',
#  'first theres lot mini hidden costs incurred us ',
#  'air really hot shacks rest ',
#  'lucky meet monkeys enjoying sunbathing ',
#  'place windy relaxing stunning view ',
#  'place could easily dirty rain ',
#  'traditional food shops coffee shops cheap prices ',
#  'good light hiking taking photos place instagramable ',
#  'best regards indonesia',
#  'international guests visit west java always ask place always ask invited place ',
#  'amazing great alternative pre wedding photo near another geopark named gua pawon archeological site contains cave man fossil',
#  'spend least min explore take pictures ',
#  'many spots take pictures ',
#  'pretty nice ',
#  'cool',
#  'way get less guidance rocky road probably name stone garden',
#  'cheap places eat ',
#  'unfortunately paids spot quite expensive rp thousand one spot rp thousand spots mistaken ',
#  ...]

# %% [markdown]
# Converting sentiment labels to 0 & 1

# %%
# Converting sentiment labels to 0 & 1

y = df['target']

# %% [markdown]
# The train set will be used to train our deep learning models
# while test set will be used to evaluate how well our model performs

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# The train set will be used to train our deep learning models
# while test set will be used to evaluate how well our model performs

# %% [markdown]
# ## Preparing embedding layer

# %% [markdown]
# Embedding layer expects the words to be in numeric form
#
# Using Tokenizer function from keras.preprocessing.text library
#
# Method fit_on_text trains the tokenizer
#
# Method texts_to_sequences converts sentences to their numeric form

# %%
word_tokenizer = Tokenizer()
word_tokenizer.fit_on_texts(X_train)

X_train = word_tokenizer.texts_to_sequences(X_train)
X_test = word_tokenizer.texts_to_sequences(X_test)

# %% [markdown]
# Adding 1 to store dimensions for words for which no pretrained word embeddings exist

# %%
vocab_length = len(word_tokenizer.word_index) + 1

vocab_length
# Out:
# 3244

# %% [markdown]
# Padding all reviews to fixed length 100

# %%
# Padding all reviews to fixed length 100

maxlen = 100

X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %% [markdown]
# Load GloVe word embeddings and create an Embeddings Dictionary

# %%
from numpy import asarray
from numpy import zeros

embeddings_dictionary = dict()
glove_file = open('/content/drive/Othercomputers/My Laptop/Bangkit Academy/capstone project/a2_glove.6B.100d.txt', encoding="utf8")

for line in glove_file:
    records = line.split()
    word = records[0]
    vector_dimensions = asarray(records[1:], dtype='float32')
    embeddings_dictionary [word] = vector_dimensions
glove_file.close()

# %% [markdown]
# Create Embedding Matrix having 100 columns
#
# Containing 100-dimensional GloVe word embeddings for all words in our corpus.

# %%
embedding_matrix = zeros((vocab_length, 100))
for word, index in word_tokenizer.word_index.items():
    embedding_vector = embeddings_dictionary.get(word)
    if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector

# %% [markdown]
# Do embedding_metrix.shape to know embedding matrix rows and columns

# %%
embedding_matrix.shape
# Out:
# (3244, 100)

# %% [markdown]
# ## Model Training

# %% [markdown]
# Create a neural network architecture using **CNN Model** to make model training :
# Convolution 1D, ReLu, Sigmoid, optimizer Adam, and Binary Crossentropy

# %%
# Neural Network architecture

cnn_model = Sequential()

embedding_layer = Embedding(vocab_length, 100, weights=[embedding_matrix], input_length=maxlen , trainable=False)
cnn_model.add(embedding_layer)

cnn_model.add(Conv1D(128, 5, activation='relu'))
cnn_model.add(GlobalMaxPooling1D())
cnn_model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# Create a model compiling and print the summary model

# %%
# Model compiling

cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
print(cnn_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 100)          324400
#
#  conv1d (Conv1D)             (None, 96, 128)           64128
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 388,657
# Trainable params: 64,257
# Non-trainable params: 324,400
# _________________________________________________________________
# None

# %% [markdown]
# Train the model with 50 epochs

# %%
# Model training

cnn_model_history = cnn_model.fit(X_train, y_train, batch_size=128, epochs=50, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 15/15 [==============================] - 10s 50ms/step - loss: 0.5913 - acc: 0.7017 - val_loss: 0.5358 - val_acc: 0.7473
# Epoch 2/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.4373 - acc: 0.8097 - val_loss: 0.4855 - val_acc: 0.7625
# Epoch 3/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3627 - acc: 0.8582 - val_loss: 0.4725 - val_acc: 0.7821
# Epoch 4/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3126 - acc: 0.8850 - val_loss: 0.4637 - val_acc: 0.8017
# Epoch 5/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2756 - acc: 0.9073 - val_loss: 0.4833 - val_acc: 0.7887
# Epoch 6/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.2457 - acc: 0.9220 - val_loss: 0.4556 - val_acc: 0.7974
# Epoch 7/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.2182 - acc: 0.9335 - val_loss: 0.4539 - val_acc: 0.7887
# Epoch 8/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1964 - acc: 0.9466 - val_loss: 0.4579 - val_acc: 0.7974
# Epoch 9/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1737 - acc: 0.9542 - val_loss: 0.4678 - val_acc: 0.7996
# Epoch 10/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1544 - acc: 0.9667 - val_loss: 0.4629 - val_acc: 0.7974
# Epoch 11/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1388 - acc: 0.9711 - val_loss: 0.4721 - val_acc: 0.7974
# Epoch 12/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.1269 - acc: 0.9733 - val_loss: 0.4740 - val_acc: 0.8061
# Epoch 13/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.1154 - acc: 0.9755 - val_loss: 0.4783 - val_acc: 0.7996
# Epoch 14/50
# 15/15 [==============================] - 0s 11ms/step - loss: 0.1033 - acc: 0.9815 - val_loss: 0.4847 - val_acc: 0.7996
# Epoch 15/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0954 - acc: 0.9809 - val_loss: 0.4927 - val_acc: 0.7865
# Epoch 16/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0870 - acc: 0.9820 - val_loss: 0.4999 - val_acc: 0.7952
# Epoch 17/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0799 - acc: 0.9842 - val_loss: 0.5008 - val_acc: 0.7865
# Epoch 18/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0739 - acc: 0.9847 - val_loss: 0.5144 - val_acc: 0.7930
# Epoch 19/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0678 - acc: 0.9847 - val_loss: 0.5183 - val_acc: 0.7930
# Epoch 20/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0659 - acc: 0.9864 - val_loss: 0.5242 - val_acc: 0.7843
# Epoch 21/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0608 - acc: 0.9875 - val_loss: 0.5334 - val_acc: 0.7865
# Epoch 22/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0560 - acc: 0.9880 - val_loss: 0.5445 - val_acc: 0.7908
# Epoch 23/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0519 - acc: 0.9891 - val_loss: 0.5507 - val_acc: 0.7843
# Epoch 24/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0489 - acc: 0.9896 - val_loss: 0.5553 - val_acc: 0.7887
# Epoch 25/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0463 - acc: 0.9913 - val_loss: 0.5542 - val_acc: 0.7821
# Epoch 26/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0439 - acc: 0.9907 - val_loss: 0.5819 - val_acc: 0.7821
# Epoch 27/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0417 - acc: 0.9918 - val_loss: 0.5700 - val_acc: 0.7843
# Epoch 28/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0413 - acc: 0.9924 - val_loss: 0.6048 - val_acc: 0.7821
# Epoch 29/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0377 - acc: 0.9929 - val_loss: 0.6048 - val_acc: 0.7800
# Epoch 30/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0368 - acc: 0.9924 - val_loss: 0.5907 - val_acc: 0.7843
# Epoch 31/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0345 - acc: 0.9935 - val_loss: 0.6011 - val_acc: 0.7843
# Epoch 32/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0334 - acc: 0.9924 - val_loss: 0.5959 - val_acc: 0.7625
# Epoch 33/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0323 - acc: 0.9913 - val_loss: 0.6009 - val_acc: 0.7734
# Epoch 34/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0306 - acc: 0.9940 - val_loss: 0.6163 - val_acc: 0.7778
# Epoch 35/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0315 - acc: 0.9924 - val_loss: 0.6070 - val_acc: 0.7625
# Epoch 36/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0283 - acc: 0.9918 - val_loss: 0.6276 - val_acc: 0.7691
# Epoch 37/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0270 - acc: 0.9935 - val_loss: 0.6247 - val_acc: 0.7712
# Epoch 38/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0274 - acc: 0.9918 - val_loss: 0.6256 - val_acc: 0.7712
# Epoch 39/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0262 - acc: 0.9940 - val_loss: 0.6529 - val_acc: 0.7778
# Epoch 40/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0253 - acc: 0.9935 - val_loss: 0.6462 - val_acc: 0.7756
# Epoch 41/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0337 - acc: 0.9924 - val_loss: 0.6610 - val_acc: 0.7778
# Epoch 42/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0304 - acc: 0.9940 - val_loss: 0.6634 - val_acc: 0.7734
# Epoch 43/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0247 - acc: 0.9940 - val_loss: 0.6597 - val_acc: 0.7734
# Epoch 44/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0232 - acc: 0.9929 - val_loss: 0.6574 - val_acc: 0.7734
# Epoch 45/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0216 - acc: 0.9935 - val_loss: 0.6598 - val_acc: 0.7647
# Epoch 46/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0220 - acc: 0.9924 - val_loss: 0.6629 - val_acc: 0.7691
# Epoch 47/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0215 - acc: 0.9940 - val_loss: 0.7195 - val_acc: 0.7756
# Epoch 48/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0222 - acc: 0.9940 - val_loss: 0.6610 - val_acc: 0.7669
# Epoch 49/50
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0195 - acc: 0.9940 - val_loss: 0.6971 - val_acc: 0.7691
# Epoch 50/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0210 - acc: 0.9935 - val_loss: 0.7369 - val_acc: 0.7669

# %% [markdown]
# Make predictions on the test set how much loss value and accuracy value

# %%
# Predictions on the Test Set

score = cnn_model.evaluate(X_test, y_test, verbose=1)
# Out:
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5787 - acc: 0.7979

# %% [markdown]
# Print the model performance include test score and test accuracy

# %%
# Model Performance

print("Test Score:", score[0])
print("Test Accuracy:", score[1])
# Out:
# Test Score: 0.5786847472190857
# Test Accuracy: 0.7979093790054321

# %% [markdown]
# Make the line chart to compare the model accuracy and model loss

# %%
# Model Performance Charts

import matplotlib.pyplot as plt

plt.plot(cnn_model_history.history['acc'])
plt.plot(cnn_model_history.history['val_acc'])

plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

plt.plot(cnn_model_history.history['loss'])
plt.plot(cnn_model_history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc = 'upper left')
plt.show()

# %% [markdown]
# Saving the model as a h5 file for possible use later

# %%
cnn_model.save(f"./c1_lstm_model_acc_{round(score[1], 3)}.h5", save_format='h5')

# %% [markdown]
# ## Making Prediction From the Data

# %% [markdown]
# Show the top 6 dataset from the dataframe

# %%
# Load sample data

df.head(6)
# Out:
#    target                                              texts
# 0       0         Monday, Many tours in Surabaya are closed.
# 1       1  Great Place for sightseeing and spending time ...
# 2       1  Cool place, comfortable, clean, unlike other s...
# 3       1  Place of education for the citizens of Surabay...
# 4       1                                        Really good
# 5       1                                Lots of good smooth

# %% [markdown]
# Preprocess review text with earlier defined preprocess_text function

# %%
reviews =df['texts']

processed = []
for review in reviews:
  review = preprocess_text(review)
  processed.append(review)

# %% [markdown]
# Make Tokenising instance with earlier trained tokeniser and Pooling instance to have maxlength of 100 tokens

# %%
# Tokenising instance with earlier trained tokeniser
tokenized2 = word_tokenizer.texts_to_sequences(processed)

# Pooling instance to have maxlength of 100 tokens
padded2 = pad_sequences(tokenized2, padding='post', maxlen=maxlen)

# %% [markdown]
# Passing tokenised instance to the **CNN model** for predictions

# %%
sentiments = cnn_model.predict(padded2)

sentiments
# Out:
# 90/90 [==============================] - 0s 3ms/step
# array([[0.00112567],
#        [0.9999974 ],
#        [0.99996746],
#        ...,
#        [0.00935577],
#        [0.08203949],
#        [0.9992884 ]], dtype=float32)

# %% [markdown]
#  Writing model output file back to Google Drive

# %%
df['Predicted Sentiments'] = np.round(sentiments*10,1)

df_prediction_sentiments = pd.DataFrame(df['Predicted Sentiments'], columns = ['Predicted Sentiments'])
df_target                = pd.DataFrame(df['target'], columns = ['target'])
df_texts                 = pd.DataFrame(df['texts'], columns = ['texts'])


dfx=pd.concat([df_target, df_texts, df_prediction_sentiments], axis=1)

dfx.to_csv("./c2_IMDb_Predictions.csv", sep=',', encoding='UTF-8')

dfx.head(6)
# Out:
#    target                                              texts  \
# 0       0         Monday, Many tours in Surabaya are closed.
# 1       1  Great Place for sightseeing and spending time ...
# 2       1  Cool place, comfortable, clean, unlike other s...
# 3       1  Place of education for the citizens of Surabay...
# 4       1                                        Really good
# 5       1                                Lots of good smooth
#
#    Predicted Sentiments
# 0                   0.0
# 1                  10.0
# 2                  10.0
# 3                  10.0
# 4                   9.2
# 5                  10.0

# %% [markdown]
# Show the result of prediction

# %%
sentence2 = ["Its a nice place to escape the busy life of Surabaya. The park is simple yet beautiful, clean and well maintained."]

tokenized22 = word_tokenizer.texts_to_sequences(sentence2)
# Pooling instance to have maxlength of 100 tokens
padded22 = pad_sequences(tokenized22, padding='post', maxlen=maxlen)


print(cnn_model.predict(padded22))
# Out:
# 1/1 [==============================] - 0s 53ms/step
# [[0.99406624]]

# %% [markdown]
# # **Convert to Tflite**

# %% [markdown]
# Converting TensorFlow models to TensorFlow Lite format can take a few paths depending on the content of your ML model. As the first step of that process, you should evaluate your model to determine if it can be directly converted. This evaluation determines if the content of the model is supported by the standard TensorFlow Lite runtime environments based on the TensorFlow operations it uses. If your model uses operations outside of the supported set, you have the option to refactor your model or use advanced conversion techniques.
#
# 1. Converting a tf.Keras model to a TensorFlow Lite model
# 2. Keras model: A model created using the high level Keras API.
# 3. Open the model.tflite to connect deploy

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(cnn_model)
tflite_model = converter.convert()

with open("model.tflite", 'wb') as f:
  f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
